# %% [markdown]
# # 11장 타이머55

# %% [markdown]
# * 이름: 홍길동
# * 학번: 2025123456
# * 조: 1

# %% [markdown]
# ## 공통 코드

# %%
import sys
from pathlib import Path

# common_dir = Path.cwd().parent / "ece2knu_common"
common_dir = Path.cwd()
sys.path.insert(0, str(common_dir))

from common import *

# %% [markdown]
# *******************************************************************************

# %% [markdown]
# ## 11.5 실험 내용

# %% [markdown]
# ### 실험01 슈미트트리거

# %% [markdown]
# #### 실험01-01 회로 구성

# %% [markdown]
# 다음 회로를 만들어보자.

# %% [markdown]
# * Timer 555
#     + 전원공급: Vcc(8번)=5V, Ground(1번)
#     + 리셋(4번) : Vcc를 공급

# %%
display_image("./images/ch11_05_timer555.png", width=400)

# %%
display_image("./images/ch11_05_ep01_01_circuit.png", width=300)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch11_05_ep01_01_circuit_hardware.png", width=700)

# %% [markdown]
# #### 실험01-02 출력값의 확인

# %% [markdown]
# 직류를 인가해보자. (직류는 파형발생기로 공급한다)
#
# * 출력이 V_H 가 되기 위해서는 입력을 V_i < V_TL 를 인가하면 된다.
# * 출력이 V_L 가 되기 위해서는 입력을 V_TH < V_i 를 인가하면 된다.

# %% [markdown]
# | v_i (V)         | v_o 측정값 (V)  | v_o 예시값 (V)      | 상태            |
# |-----------------|-----------------|---------------------|-----------------|
# | 0               | ??              | V_CC 보다 조금 작다 | V_H             |
# | 5               | ??              | 거의 0              | V_L             |

# %% [markdown]
# #### 실험01-03 순차적인 직류전 입력 동작확인

# %% [markdown]
# 다음과 같이 순차적으로 직류를 인가해보자. (직류는 파형발생기로 공급한다)
#
# * 0, 2, 4, 2, 0 V
#
# 출력이 V_H (약 4.43V) 값이 나오면 1 (논리값 1) 로 거의 0 이 나오면 0 (논리값 0) 으로 기록한다.

# %% [markdown]
# | 경우 | v_i (V) | R S | 출력값 측정 (V) | 출력값 에시 (V) |
# |------|---------|-----|-----------------|-----------------|
# | 1    | 0       | 0 1 | ??              | 1               |
# | 2    | 2       | 0 0 | ??              | 1               |
# | 3    | 4       | 1 0 | ??              | 0               |
# | 4    | 2       | 0 0 | ??              | 0               |
# | 5    | 0       | 0 1 | ??              | 1               |

# %% [markdown]
# #### 실험01-04 교류인가 + 입출력 전달특성곡선

# %% [markdown]
# 입력 v_i 에 정현파를 인가하자 (파형발생기를 이용)
#
# * 주파수: 50 Hz
# * 크기  : 5 V_PP
# * 오프셋: 2.5 V

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch11_05_ep01_04_result_plot.png", width=700)

# %% [markdown]
# XY모드로 설정한다.

# %%
display_image("./data/ch11_05_ep01_04_result_plot_xy.png", width=700)

# %% [markdown]
# ### 실험02 Astable MV회로1

# %% [markdown]
# 다음 회로를 만들어보자.

# %% [markdown]
# * Timer 555
#     + 전원공급: Vcc(8번)=5V, Ground(1번)
#     + 리셋(4번) : Vcc를 공급

# %%
display_image("./images/ch11_05_ep02_01_circuit.png", width=500)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch11_05_ep02_01_circuit_hardware.png", width=700)

# %% [markdown]
# V_CC 로 5 V 를 공급한다.

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch11_05_ep02_01_result_plot.png", width=700)

# %% [markdown]
# 자동측정으로 출력의 주파수와 튜티사이클을 측정한다.

# %% [markdown]
# |                      | 측정        | 예시값  |
# |----------------------|-------------|---------|
# | 주파수 (Hz)          | ??          | 447     |
# | 듀티사이클 (Percent) | ??          | 71.99   |

# %% [markdown]
# Vcc를 증가시켜보자. (Vcc = 10V)

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch11_05_ep02_02_result_plot.png", width=700)

# %% [markdown]
# 자동측정으로 출력의 주파수와 튜티사이클을 측정한다.

# %% [markdown]
# |                      | 측정        | 예시값  |
# |----------------------|-------------|---------|
# | 주파수 (Hz)          | ??          | 672     |
# | 듀티사이클 (Percent) | ??          | 58.72   |

# %% [markdown]
# [결론] 주파수가 Vcc에 따라 바뀌는 단점을 가진다.

# %% [markdown]
# ### 실험03 Astable MV2 : 듀티사이클 66.7%

# %% [markdown]
# 다음 회로를 만들어보자.

# %% [markdown]
# * Timer 555
#     + 전원공급: Vcc(8번)=5V, Ground(1번)
#     + 리셋(4번) : Vcc를 공급

# %%
display_image("./images/ch11_05_ep03_01_circuit.png", width=500)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch11_05_ep03_01_circuit_hardware.png", width=700)

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch11_05_ep03_01_result_plot.png", width=700)

# %% [markdown]
# 자동측정으로 출력의 t_1, t_2, 주파수와 튜티사이클을 측정한다.

# %% [markdown]
# |                 | 측정값 (V)       | 예시값 (V)      | 이론값 (V)      |
# |-----------------|------------------|-----------------|-----------------|
# | frequency (Hz)  | ??               | 447             | 483             |
# | t_1 (ms)        | ??               | 1.271           | 1.380           |
# | t_2 (ms)        | ??               | 0.672           | 0.690           |
# | duty (percent)  | ??               | 71.99           | 66.7            |

# %% [markdown]
# ### 실험04 Astable MV2 : 듀티사이클 50%

# %% [markdown]
# 다음 회로를 만들어보자.

# %% [markdown]
# * Timer 555
#     + 전원공급: Vcc(8번)=5V, Ground(1번)
#     + 리셋(4번) : Vcc를 공급

# %%
display_image("./images/ch11_05_ep04_01_circuit.png", width=500)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch11_05_ep04_01_circuit_hardware.png", width=700)

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch11_05_ep04_01_result_plot.png", width=700)

# %% [markdown]
# 자동측정으로 출력의 t_1, t_2, 주파수와 튜티사이클을 측정한다.

# %% [markdown]
# |                 | 측정값 (V)       | 예시값 (V)      | 이론값 (V)      |
# |-----------------|------------------|-----------------|-----------------|
# | frequency (Hz)  | ??               | 713             | 724             |
# | t_1 (ms)        | ??               | 0.699           | 0.690           |
# | t_2 (ms)        | ??               | 0.702           | 0.690           |
# | duty (percent)  | ??               | 49.88           | 50              |

# %% [markdown]
# ### 실험05 Astable MV2 : 듀티사이클 33%

# %% [markdown]
# 다음 회로를 만들어보자.

# %% [markdown]
# * Timer 555
#     + 전원공급: Vcc(8번)=5V, Ground(1번)
#     + 리셋(4번) : Vcc를 공급

# %%
display_image("./images/ch11_05_ep05_01_circuit.png", width=500)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch11_05_ep05_01_circuit_hardware.png", width=700)

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch11_05_ep05_01_result_plot.png", width=700)

# %% [markdown]
# 자동측정으로 출력의 t_1, t_2, 주파수와 튜티사이클을 측정한다.

# %% [markdown]
# |                 | 측정값 (V)       | 예시값 (V)      | 이론값 (V)      |
# |-----------------|------------------|-----------------|-----------------|
# | frequency (Hz)  | ??               | 924.7           | 1000            |
# | t_1 (ms)        | ??               | 0.398           | 0.345           |
# | t_2 (ms)        | ??               | 0.683           | 0.690           |
# | duty (percent)  | ??               | 36.86           | 33.3            |

# %% [markdown]
# ### 실험06 Astable MV2 : 눈으로 관측하기

# %% [markdown]
# 다음 회로를 만들어보자.

# %% [markdown]
# * Timer 555
#     + 전원공급: Vcc(8번)=5V, Ground(1번)
#     + 리셋(4번) : Vcc를 공급

# %%
display_image("./images/ch11_05_ep06_01_circuit.png", width=500)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch11_05_ep06_01_circuit_hardware.png", width=700)

# %% [markdown]
# [결과] 1초를 주기로 깜빡인다.

# %% [markdown]
# ### 실험07 Monostable MV : 멜로디 IC를 구동해보자.

# %% [markdown]
# 다음 회로를 만들어보자.

# %% [markdown]
# * Timer 555
#     + 전원공급: Vcc(8번)=5V, Ground(1번)
#     + 리셋(4번) : Vcc를 공급

# %%
display_image("./images/ch11_05_ep07_01_circuit.png", width=500)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch11_05_ep07_01_circuit_hardware.png", width=700)

# %% [markdown]
# 결과 : 스위치를 누르면 10초동안 멜로디가 들린다.

# %% [markdown]
# ### 실험08 금지된 입력의 해결

# %% [markdown]
# ### 실험08-01 NOT 게이트를 이용

# %% [markdown]
# 다음 회로를 만들어보자.

# %% [markdown]
# * NOT게이트: 74HC04

# %%
display_image("./images/ch11_05_74hc04.png", width=300)

# %%
display_image("./images/ch11_05_ep08_01_circuit.png", width=500)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch11_05_ep08_01_circuit_hardware.png", width=700)

# %% [markdown]
# 입력 v_i 에 삼각파를 인가하자 (파형발생기를 이용)
#
# * 주파수: 1 kHz
# * 진폭: 5 V_PP
# * 오프셋: 2.5 V (고전압: 5 V, 저전압; 0 V)

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch11_05_ep08_01_result_plot.png", width=700)

# %% [markdown]
# [검토] 금지영역에 해당하는 입력범위에서 굉장히 많은 에지들이 발생하는 나쁜 효과가 생긴다.

# %% [markdown]
# ### 실험08-02 슈미트트리거 이용

# %% [markdown]
# 다음 회로를 만들어보자.

# %% [markdown]
# * Timer 555
#     + 전원공급: Vcc(8번)=5V, Ground(1번)
#     + 리셋(4번) : Vcc를 공급

# %%
display_image("./images/ch11_05_ep08_02_circuit.png", width=500)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch11_05_ep08_02_circuit_hardware.png", width=700)

# %% [markdown]
# 입력 v_i 에 삼각파를 인가하자 (파형발생기를 이용)
#
# * 주파수: 1 kHz
# * 진폭: 5 V_PP
# * 오프셋: 2.5 V (고전압: 5 V, 저전압; 0 V)

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o
#
# * Filtervu Noise Filter
#     + 노이즈필터 포그라운드 > 140 kHz
#     + 글리치포작 백그라운드 > 설정

# %%
display_image("./data/ch11_05_ep08_02_result_plot.png", width=700)

# %% [markdown]
# [검토] 깨끗한 에지만 나타난다.

# %% [markdown]
# ### 실험09 경찰차 경광등

# %% [markdown]
# 다음 회로를 만들어보자.

# %% [markdown]
# * Timer 555
#     + 전원공급: Vcc(8번)=5V, Ground(1번)
#     + 리셋(4번) : Vcc를 공급

# %%
display_image("./images/ch11_05_ep09_01_circuit.png", width=800)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch11_05_ep09_01_circuit_hardware.png", width=700)

# %% [markdown]
# 결과 : 왼쪽 LED와 오른쪽 LED가 번갈아 빤짝인다.
