# %% [markdown]
# # 11장 타이머55

# %% [markdown]
# * 이름: 홍길동
# * 학번: 2025123456
# * 조: 1

# %% [markdown]
# ## 공통 코드

# %%
import sys
from pathlib import Path

# common_dir = Path.cwd().parent / "ece2knu_common"
common_dir = Path.cwd()
sys.path.insert(0, str(common_dir))

from common import *

# %% [markdown]
# *******************************************************************************

# %% [markdown]
# ## 11.4 예비 문제

# %% [markdown]
# ### 11.4.1 그림 11.11 비안정 멀티바이브레이터의 출력파형에서 양의 전압이 유지되는 시간 t_1 을 구하시오. (답: t_1 ~= 0.69 (R_A + R_B) C)

# %%
display_image("./images/ch11_04_01_circuit.png", width=400)

# %%
display_image("./images/ch11_04_01_saveform.png", width=500)

# %%
display_image("./data/ch11_04_01_calc_1.png", width=600)

# %% [markdown]
# ### 11.4.2 실험3의 비안정멀티바이브레이터의 동작을 KiCad로 검증하시오.

# %% [markdown]
# 타이머 555를 이용한 Astable MV2회로
#
# * 사용 소자
#     + NE555: Place Symbols > NE555P
#         - Simulation Model: NE555.lib > NE555

# %%
display_image("./images/ch11_04_02_circuit.png", width=400)

# %% [markdown]
# 참고용 CAD 회로도

# %%
display_image("./images/ch11_04_02_circuit_cad_ref.png", width=700)

# %% [markdown]
# 시뮬레이션 설정

# %%
display_image("./images/ch11_04_02_sim_setting_ref.png", width=700)

# %% [markdown]
# 작성한 CAD 회로도

# %%
display_image("./data/ch11_04_02_circuit_cad.png", width=700)

# %% [markdown]
# 시뮬레이션 결과 그래프 관찰

# %%
display_image("./data/ch11_04_02_plot.png", width=700)

# %% [markdown]
# 시뮬레이션 결과 데이터 분석

# %% [markdown]
# 그래프를 그린다.

# %%
# 실험 결과 파일을 읽는다.
data = get_simulation_result_kicad('./data/ch11_04_02_data.csv')

# 실험 결과에서 시간, 입력 전압, 출력 전압을 가져온다.
times = data['time']
vch1 = data['V(/ch1)']
vch2 = data['V(/ch2)']

# # 필터를 적용해 잡음을 줄인다.
# vch1 = savgol_filter(vch1, 100, 2)
# vch2 = savgol_filter(vch2, 100, 2)

# 시간을 x축, 전압들을 y축으로 하는 그래프를 그린다.
plt.xlabel('TIME_s')
plt.ylabel('V_V')
plt.axhline(0, color='black')
plt.axvline(0.01, color='black')
draw_plot(times, vch1, 'V(CH1)', 0)
draw_plot(times, vch2, 'V(CH2)', 1)
plt.show()

# %% [markdown]
# frequency, t_1, t_2, duty 를 구한다.

# %%
frequency_Hz, t_1_s, t_2_s, duty_percent = calculate_square_wave_frequency_t1_t2_duty(times, vch2)
t_1_ms = t_1_s * 1000
t_2_ms = t_2_s * 1000
print_value("frequency_Hz", frequency_Hz)
print_value("t_1_ms", t_1_ms)
print_value("t_2_ms", t_2_ms)
print_value("duty_percent", duty_percent)

# %% [markdown]
# |                 | 시뮬레이션값 (V) | 예시값 (V)      |
# |-----------------|------------------|-----------------|
# | frequency (Hz)  | ??               | 470             |
# | t_1 (ms)        | ??               | 1.4             |
# | t_2 (ms)        | ??               | 0.7             |
# | duty (percent)  | ??               | 65              |
