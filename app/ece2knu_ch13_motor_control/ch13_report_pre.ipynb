# %% [markdown]
# # 13장 모터 제어

# %% [markdown]
# * 이름: 홍길동
# * 학번: 2025123456
# * 조: 1

# %% [markdown]
# ## 공통 코드

# %%
import sys
from pathlib import Path

# common_dir = Path.cwd().parent / "ece2knu_common"
common_dir = Path.cwd()
sys.path.insert(0, str(common_dir))

from common import *

# %% [markdown]
# *******************************************************************************

# %% [markdown]
# ## 13.4 예비 문제

# %% [markdown]
# ### 13.4.1 L298N 모터드라이버의 데이터시트를 찾아보고 기능을 이해하자. (기능을 간단히 요악해보자.)

# %%
display_image("./data/ch13_04_01_report.png", width=600)

# %% [markdown]
# ### 13.4.2 PWM 제어가 무엇인지 구체적으로 알아보고, 적용 예를 조사해 보자.

# %%
display_image("./data/ch13_04_02_report.png", width=600)

# %% [markdown]
# ### 13.4.3 DC 모터의 종류와 특성을 조사해 보자.

# %%
display_image("./data/ch13_04_03_report.png", width=600)

# %% [markdown]
# ### 13.4.4 스위치를 이용한 논리값의 입력시에 풀업저항과 풀다운저항에 대해서 조사해 보자.

# %%
display_image("./data/ch13_04_04_report.png", width=600)
