# %% [markdown]
# # 09장 오디오증폭기

# %% [markdown]
# * 이름: 홍길동
# * 학번: 2025123456
# * 조: 1

# %% [markdown]
# ## 공통 코드

# %%
import sys
from pathlib import Path

# common_dir = Path.cwd().parent / "ece2knu_common"
common_dir = Path.cwd()
sys.path.insert(0, str(common_dir))

from common import *

# %% [markdown]
# *******************************************************************************

# %% [markdown]
# ## 9.5 실험 내용

# %% [markdown]
# ### 실험01 이득이 -5인 CE증폭기회로

# %% [markdown]
# 다음 회로를 만들어보자.

# %% [markdown]
# * 트랜지스터: 2N2222

# %%
display_image("./images/ch09_05_ep01_01_circuit.png", width=600)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch09_05_ep01_01_circuit_hardware.png", width=700)

# %% [markdown]
# 먼저, 커패시터를 연결하지 않는 상태에서 실험한다.

# %% [markdown]
# V_CE 값을 측정하라.

# %% [markdown]
# |                 | 측정값 (V)      | 예시값 (V)      | 이론값 (V)      |
# |-----------------|-----------------|-----------------|-----------------|
# | V_CE            | ??              | 7.2             | 7.463           |

# %% [markdown]
# 전해커패시터의 극성을 확인하여 연결하라.

# %% [markdown]
# 입력 v_i 에 정현파를 인가하자 (파형발생기를 이용)
#
# * 주파수: 1 kHz
# * 크기  : 2 V_PP

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %% [markdown]
# 출력의 크기가 10 V_PP 가 되도록 가변저항을 조절한 후 측정한다. (출력의 크기는 오실로스코프의 자동측정 기능으로 확인하면 된다.)

# %%
display_image("./data/ch09_05_ep01_01_result_plot.png", width=700)

# %% [markdown]
# ### 실험02 CC증폭기회로

# %% [markdown]
# 다음 회로를 만들어보자.

# %% [markdown]
# * 트랜지스터: 2N2222

# %%
display_image("./images/ch09_05_ep02_01_circuit.png", width=600)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch09_05_ep02_01_circuit_hardware.png", width=700)

# %% [markdown]
# 먼저, 커패시터를 연결하지 않는 상태에서 실험한다.

# %% [markdown]
# V_CE 값을 측정하라.

# %% [markdown]
# |                 | 측정값 (V)      | 예시값 (V)      | 이론값 (V)      |
# |-----------------|-----------------|-----------------|-----------------|
# | V_CE            | ??              | 7.1             | 7.15            |

# %% [markdown]
# 전해커패시터의 극성을 확인하여 연결하라.

# %% [markdown]
# 입력 v_i 에 정현파를 인가하자 (파형발생기를 이용)
#
# * 주파수: 1 kHz
# * 크기  : 2 V_PP

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %% [markdown]
# 출력이 발진하면 VCC 와 GND 사이에 세라믹커패시터(0.1 uF) 을 연결한다.

# %%
display_image("./data/ch09_05_ep02_01_result_plot.png", width=700)

# %% [markdown]
# R_o 를 측정한다.
# * 출력저항이 매우 작으므로, 가변저항을 이용하는 방법보다, 고정저항을 이용하는 방법으로 측정한다.
# * 다음과 같이 부하저항 R_L = 100 Ohm 을 달아준다.

# %%
display_image("./images/ch09_05_ep02_02_circuit.png", width=600)

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch09_05_ep02_02_result_plot.png", width=700)

# %% [markdown]
# R_o 값을 계산한다.

# %%
V_i_V_PP = ??
V_o_V_PP = ??

# %%
R_L_Ohm = 100
A_v = 1

R_o_Ohm = R_L_Ohm * (A_v * V_i_V_PP - V_o_V_PP) / V_o_V_PP

print_value("R_o_Ohm", R_o_Ohm)

# %% [markdown]
# ### 실험03 이득이 -5인 CE-CC종속증폭회로

# %% [markdown]
# 다음 회로를 만들어보자.

# %% [markdown]
# * 트랜지스터: 2N2222

# %%
display_image("./images/ch09_05_ep03_01_circuit.png", width=600)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch09_05_ep03_01_circuit_hardware.png", width=700)

# %% [markdown]
# 먼저, 커패시터를 연결하지 않는 상태에서 실험한다.

# %% [markdown]
# V_CE 값을 측정하라.

# %% [markdown]
# |                 | 측정값 (V)      | 예시값 (V)      | 이론값 (V)      |
# |-----------------|-----------------|-----------------|-----------------|
# | V_CE_1          | ??              | 7.1             | 7.463           |
# | V_CE_2          | ??              | 6.79            | 6.3             |

# %% [markdown]
# 전해커패시터의 극성을 확인하여 연결하라.

# %% [markdown]
# 입력 v_i 에 정현파를 인가하자 (파형발생기를 이용)
#
# * 주파수: 1 kHz
# * 크기  : 600 mV_PP

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %% [markdown]
# * 채널 1과 채널 2의 0V 기준점을 화면의 중앙에 오도록 한다.
# * 채널 2의 직류전압 성분을 제거하기 위하여, 채널 2의 커플링을 AC모드로 변환한다.
# * 가변저항을 조절하여 이득이 –5가 되도록 만든다.
# * 자동측정으로 출력의 V_PP 를 측정한다.

# %%
display_image("./data/ch09_05_ep03_01_result_plot.png", width=700)

# %% [markdown]
# 부하효과를 실험한다.
#
# * 다음 회로와 같이 부하저항에 200 Ohm을 연결한다.

# %%
display_image("./images/ch09_05_ep03_02_circuit.png", width=600)

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch09_05_ep03_02_result_plot.png", width=700)

# %% [markdown]
# 결과값을 기록한다.

# %% [markdown]
# |                 | 측정값 (V)      | 예시값 (V)      |
# |-----------------|-----------------|-----------------|
# | 무부하          | ??              | 3.08            |
# | 부하            | ??              | 2.84            |

# %% [markdown]
# * 결론: 부하효과가 미미하다.

# %% [markdown]
# ### 실험04 PC의 소리를 스피커로 들어보자.

# %% [markdown]
# 헤드셋의 출력은 3선으로 나온다. (기준선과 좌우출력선)

# %%
display_image("./images/ch09_05_ep04_01_circuit.png", width=600)

# %% [markdown]
# 음악을 재생한다.

# %% [markdown]
# 오실로스코프로 측정해보자. (빨간선 또는 흰선에 측정하면 된다)

# %%
display_image("./images/ch09_05_ep04_02_circuit.png", width=600)

# %%
display_image("./data/ch09_05_ep04_02_result_plot.png", width=700)

# %% [markdown]
# * 검토: 출력값의 피크값이 약 600mV 정도가 나온다.

# %% [markdown]
# 헤드셋 출력을 스피커에 직접 연결한다

# %%
display_image("./images/ch09_05_ep04_03_circuit.png", width=600)

# %% [markdown]
# 오실로스코프로 측정해보자.

# %%
display_image("./data/ch09_05_ep04_03_result_plot.png", width=700)

# %% [markdown]
# * 검토: 소리의 크기가 엄청 줄었다!!! 이유가 무엇일까???

# %% [markdown]
# ## 실험05 오디오증폭기로 소리를 들어보자.

# %% [markdown]
# 다음 회로를 만들어보자.

# %%
display_image("./images/ch09_05_ep05_01_diagram.png", width=600)

# %% [markdown]
# 다음 회로를 만들어보자.

# %% [markdown]
# * 트랜지스터: 2N2222

# %%
display_image("./images/ch09_05_ep05_01_circuit.png", width=600)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch09_05_ep05_01_circuit_hardware.png", width=700)

# %% [markdown]
# 전원을 공급하고, 노래를 재생해 보자.

# %% [markdown]
# * 결과: 그럭저럭 들을 만하다.

# %% [markdown]
# ### 실험06 오디오용 앰프IC를 이용

# %% [markdown]
# 사용한 오디오용 앰프IC는 LM386이고 단자연결도는 다음과 같다.

# %%
display_image("./images/ch09_05_ep06_01_diagram.png", width=600)

# %% [markdown]
# 다음 회로를 만들어보자.

# %% [markdown]
# * 전원: V_s = 10 V (6번핀), GND(4번핀)
# * 앰프의 이득은 20으로 맞춰져 있다.
# * 10 kOhm 가변저항을 이용하여, 입력을 낮추어서, 전체이득을 조절한다.
# * 220 uF 커패시터는 직류를 제거하는 목적으로 사용되었다.

# %%
display_image("./images/ch09_05_ep06_01_circuit.png", width=600)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch09_05_ep06_01_circuit_hardware.png", width=700)

# %% [markdown]
# 음악을 들어보자.

# %% [markdown]
# * 결과: 음악이 적당하게 들린다.

# %% [markdown]
# 잡음제거를 더 해보자.

# %% [markdown]
# 다음 회로를 만들어보자.

# %% [markdown]
# * 출력단에 세라믹커패시터와 저항을 연결한다.

# %%
display_image("./images/ch09_05_ep06_02_circuit.png", width=600)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch09_05_ep06_02_circuit_hardware.png", width=700)

# %% [markdown]
# 음악을 들어보자.

# %% [markdown]
# * 결과: 음악이 좀 더 명확하게 들린다.
