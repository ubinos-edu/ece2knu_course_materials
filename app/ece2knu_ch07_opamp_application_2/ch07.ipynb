# %% [markdown]
# # 07장 연산증폭기의 응용회로 2

# %% [markdown]
# * 이름: 홍길동
# * 학번: 2025123456
# * 조: 1

# %% [markdown]
# ## 공통 코드

# %%
import sys
from pathlib import Path

# common_dir = Path.cwd().parent / "ece2knu_common"
common_dir = Path.cwd()
sys.path.insert(0, str(common_dir))

from common import *

# %% [markdown]
# *******************************************************************************

# %% [markdown]
# ## 7.3 실험 이론

# %% [markdown]
# ### 7.3.2 연산증폭기가 포함된 적분기와 미분기

# %% [markdown]
# Ngspice로 교류적분기회로를 검증하기

# %% [markdown]
# 다음 회로도를 KiCad 로 그린다.
#
# * 사용 소자
#     + uA741/OPAMP: Place Symbols > Simulation_SPICE > OPAMP
#         - Simulation Model: UA741.301.mod > UA741

# %%
display_image("./images/ch07_03_02_circuit.png", width=400)

# %%
display_image("./images/ch07_03_02_circuit_cad.png", width=700)

# %% [markdown]
# 다음 설정으로 시뮬레이션한다.

# %%
display_image("./images/ch07_03_02_sim_setting.png", width=700)

# %% [markdown]
# 시뮬레이션 결과를 확인한다.

# %%
display_image("./images/ch07_03_02_sim_result_plot.png", width=700)

# %% [markdown]
# 다음 설정으로 시뮬레이션한다.

# %%
display_image("./images/ch07_03_03_sim_setting.png", width=700)

# %% [markdown]
# 시뮬레이션 결과를 확인한다.

# %%
display_image("./images/ch07_03_03_sim_result_plot.png", width=700)
