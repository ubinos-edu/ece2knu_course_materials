# %% [markdown]
# # 07장 연산증폭기의 응용회로 2

# %% [markdown]
# * 이름: 홍길동
# * 학번: 2025123456
# * 조: 1

# %% [markdown]
# ## 공통 코드

# %%
import sys
from pathlib import Path

# common_dir = Path.cwd().parent / "ece2knu_common"
common_dir = Path.cwd()
sys.path.insert(0, str(common_dir))

from common import *

# %% [markdown]
# *******************************************************************************

# %% [markdown]
# ## 7.5 실험 내용

# %% [markdown]
# ### 실험01 RC적분기회로

# %% [markdown]
# #### 실험01-01 회로의 구성

# %% [markdown]
# 다음 회로를 만들어보자.

# %%
display_image("./images/ch07_05_ep01_01_circuit.png", width=600)

# %% [markdown]
# f_0 를 미리 계산한다.

# %%
C_F = 0.1 / 1000000
R_Ohm = 47 * 1000

f_0_Hz = 1 / (2 * np.pi * C_F * R_Ohm)

f_0_Hz = round(f_0_Hz, 0)
print_value("f_0_Hz", f_0_Hz)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch07_05_ep01_01_circuit_hardware.png", width=700)

# %% [markdown]
# #### 실험01-02 구형파인가

# %% [markdown]
# 입력 v_i 에  f >> f_0 구형파를 인가하자 (파형발생기를 이용)
#
# * 주파수: 1 kHz
# * 크기: 4 V_PP

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch07_05_ep01_02_result_plot.png", width=700)

# %% [markdown]
# 비연동성 커서를 이용하여 진폭의 측정하자.
# * 노이즈가 많은 경우에는 자동측정은 엉터리값이 될 수 있다.

# %%
display_image("./data/ch07_05_ep01_02_result_plot_cursor.png", width=700)

# %% [markdown]
# 측정 결과를 기록한다.

# %% [markdown]
# |                  | 측정값          | 예시값          |
# |------------------|-----------------|-----------------|
# | 출력의 진폭 (mV) | ??              | 200             |

# %% [markdown]
# * [퀴즈] 실험결과가 4V가 나오는 사람은 무엇을 잘못했을까요?

# %% [markdown]
# ??

# %% [markdown]
# 입력 v_i 에 f ~= f_0 인 구형파를 인가하자 (파형발생기를 이용)
#
# * 주파수: 30 Hz
# * 크기: 4 V_PP

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch07_05_ep01_02_result_plot_f_0.png", width=700)

# %% [markdown]
# 비연동성 커서를 이용하여 진폭의 측정해 기록한다.
# * 노이즈가 많은 경우에는 자동측정은 엉터리값이 될 수 있다.

# %% [markdown]
# |                  | 측정값          | 예시값          |
# |------------------|-----------------|-----------------|
# | 출력의 진폭 (V)  | ??              | 3.44            |

# %% [markdown]
# * [결과] f >> f_0 인 경우: 출력전압이 비교적으로 양호한 적분성능을 보인다, 하지만, 출력전압의 크기는 매우 작다.
# * [결과] f ~= f_0 인 경우: 출력전압의 크기는 크지만, 출력전압은 지수적인 특성이 우세하여 적분 성능은 저하된다.

# %% [markdown]
# ### 실험02 RC미분기회로

# %% [markdown]
# #### 실험02-01 회로의 구성

# %% [markdown]
# 다음 회로를 만들어보자.

# %%
display_image("./images/ch07_05_ep02_01_circuit.png", width=600)

# %% [markdown]
# f_0 를 미리 계산한다.

# %%
C_F = 0.01 / 1000000
R_Ohm = 1 * 1000

f_0_Hz = 1 / (2 * np.pi * C_F * R_Ohm)

f_0_kHz = round(f_0_Hz / 1000., 3)
print_value("f_0_kHz", f_0_kHz)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch07_05_ep02_01_circuit_hardware.png", width=700)

# %% [markdown]
# #### 실험02-02 삼각파인가

# %% [markdown]
# 입력 v_i 에  f << f_0 인 삼각파를 인가하자 (파형발생기를 이용)
#
# * 주파수: 1 kHz
# * 크기: 4 V_PP

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch07_05_ep02_02_result_plot.png", width=700)

# %% [markdown]
# 비연동성 커서를 이용하여 진폭의 측정해 기록한다.
# * 노이즈가 많은 경우에는 자동측정은 엉터리값이 될 수 있다.

# %% [markdown]
# |                  | 측정값          | 예시값          |
# |------------------|-----------------|-----------------|
# | 출력의 진폭 (mV) | ??              | 150             |

# %% [markdown]
# 입력 v_i 에 f << f_0 인 구형파를 인가하자 (파형발생기를 이용)
#
# * 주파수: 1 kHz
# * 크기: 4 V_PP

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch07_05_ep02_02_result_square_plot.png", width=700)

# %% [markdown]
# [결론] f << f_0 인 경우에는 미분기로서 잘 동작한다.

# %% [markdown]
# ### 실험03 연산증폭기가 포함된 적분기

# %% [markdown]
# #### 실험03-01 회로의 구성

# %% [markdown]
# 다음 회로를 만들어보자.

# %%
display_image("./images/ch07_05_ep03_01_circuit.png", width=600)

# %% [markdown]
# f_0 를 미리 계산한다.

# %%
C_F = 0.015 / 1000000
R_2_Ohm = 1 * 1000000

f_0_Hz = 1 / (2 * np.pi * C_F * R_2_Ohm)

f_0_Hz = round(f_0_Hz, 1)
print_value("f_0_Hz", f_0_Hz)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch07_05_ep03_01_circuit_hardware.png", width=700)

# %% [markdown]
# #### 실험03-02 구형파인가

# %% [markdown]
# 입력 v_i 에 f >> f_0 구형파를 인가하자 (파형발생기를 이용)
#
# * 주파수: 1 kHz
# * 크기: 1 V_PP

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch07_05_ep03_02_result_plot.png", width=700)

# %% [markdown]
# 비연동성 커서를 이용하여 진폭의 측정해 기록한다.
# * 노이즈가 많은 경우에는 자동측정은 엉터리값이 될 수 있다.

# %% [markdown]
# |                  | 측정값          | 예시값          |
# |------------------|-----------------|-----------------|
# | 출력의 진폭 (V)  | ??              | 1.46            |

# %% [markdown]
# 입력 v_i 에 주파수 100 Hz 구형파를 인가하자 (파형발생기를 이용)

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch07_05_ep03_02_result_100hz_plot.png", width=700)

# %% [markdown]
# 비연동성 커서를 이용하여 진폭의 측정해 기록한다.
# * 노이즈가 많은 경우에는 자동측정은 엉터리값이 될 수 있다.

# %% [markdown]
# |                  | 측정값          | 예시값          |
# |------------------|-----------------|-----------------|
# | 출력의 진폭 (V)  | ??              | 13.8            |

# %% [markdown]
# 입력 v_i 에 주파수 30 Hz 구형파를 인가하자 (파형발생기를 이용)

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch07_05_ep03_02_result_30hz_plot.png", width=700)

# %% [markdown]
# 비연동성 커서를 이용하여 진폭의 측정해 기록한다.
# * 노이즈가 많은 경우에는 자동측정은 엉터리값이 될 수 있다.

# %% [markdown]
# |                  | 측정값          | 예시값          |
# |------------------|-----------------|-----------------|
# | 출력의 진폭 (V)  | ??              | 27.6            |

# %% [markdown]
# * [결과] f >> f_0 인 경우: 출력전압이 비교적으로 양호한 적분성능을 보인다, 하지만, 출력전압의 크기는 매우 작다.
# * [결과] f >> f_0 을 만족하지 못하는 경우: 출력전압의 크기는 크지만, 출력전압은 지수적인 특성이 우세하여 적분성능은 저하된다.

# %% [markdown]
# * [퀴즈] 주파수 30Hz일 때 파형이 포화되는 이유는 무엇인가?

# %% [markdown]
# ??

# %% [markdown]
# ### 실험04 연산증폭기가 포함된 미분기

# %% [markdown]
# #### 실험04-01 회로의 구성

# %% [markdown]
# 다음 회로를 만들어보자.

# %%
display_image("./images/ch07_05_ep04_01_circuit.png", width=600)

# %% [markdown]
# f_0 를 미리 계산한다.

# %%
C_F = 0.01 / 1000000
R_1_Ohm = 510

f_0_Hz = 1 / (2 * np.pi * C_F * R_1_Ohm)

f_0_kHz = round(f_0_Hz / 1000., 1)
print_value("f_0_kHz", f_0_kHz)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch07_05_ep04_01_circuit_hardware.png", width=700)

# %% [markdown]
# #### 실험04-02 삼각파인가

# %% [markdown]
# 입력 v_i 에 f << f_0 인 삼각파를 인가하자 (파형발생기를 이용)
#
# * 주파수: 1 kHz
# * 크기: 1 V_PP

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch07_05_ep04_02_result_plot.png", width=700)

# %% [markdown]
# 입력 v_i 에 f << f_0 인 구형파를 인가하자 (파형발생기를 이용)
#
# * 주파수: 1 kHz
# * 크기: 1 V_PP

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch07_05_ep04_02_result_square_plot.png", width=700)

# %% [markdown]
# ### 실험05 1차 LPF인 RC회로

# %% [markdown]
# #### 실험05-01 회로의 구성

# %% [markdown]
# 다음 회로를 만들어보자.

# %%
display_image("./images/ch07_05_ep05_01_circuit.png", width=600)

# %% [markdown]
# f_0 를 미리 계산한다.

# %%
C_F = 0.1 / 1000000
R_Ohm = 1.5 * 1000

f_0_Hz = 1 / (2 * np.pi * C_F * R_Ohm)

f_0_kHz = round(f_0_Hz / 1000., 3)
print_value("f_0_kHz", f_0_kHz)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch07_05_ep05_01_circuit_hardware.png", width=700)

# %% [markdown]
# #### 실험05-02 차단주파수를 찾는다.

# %% [markdown]
# 입력 v_i 에 정현파를 인가하자 (파형발생기를 이용)
#
# * 주파수: 1 kHz
# * 크기: 4 V_PP

# %% [markdown]
# 진폭이 입력전압 크기의 $ 1 / \sqrt{2} $ 배가 되는 주파수를 찾는다.

# %%
V_in_V_PP = 4
V_cutoff_V_PP = V_in_V_PP / np.sqrt(2)
print_value("V_cutoff_V_PP", V_cutoff_V_PP)

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch07_05_ep05_02_result_plot.png", width=700)

# %% [markdown]
# 측정 결과를 기록한다.

# %% [markdown]
# |                      | 측정값          | 예시값          |
# |----------------------|-----------------|-----------------|
# | 차단 주파수 f_0 (Hz) | ??              | 880             |

# %% [markdown]
# #### 실험05-03 주파수응답

# %% [markdown]
# f (실험) 값을 구한다.

# %%
f_0 = ??

# %%
print_value("0.1 * f_0", 0.1 * f_0)
print_value("0.5 * f_0", 0.5 * f_0)
print_value("      f_0",   1 * f_0)
print_value("  2 * f_0",   2 * f_0)
print_value("  4 * f_0",   4 * f_0)
print_value(" 10 * f_0",  10 * f_0)
print_value(" 20 * f_0",  20 * f_0)

# %% [markdown]
# 출력 진폭 (이론)값은 다음과 같이 계산할 수 있다.
# * 출력 진폭 (이론)값: A_V_abs * 입력 진폭 (V_PP)

# %%
V_in_V_PP = 4
print_value("V_in_V_PP * 0.9950", V_in_V_PP * 0.9950)
print_value("V_in_V_PP * 0.8944", V_in_V_PP * 0.8944)
print_value("V_in_V_PP * 0.7071", V_in_V_PP * 0.7071)
print_value("V_in_V_PP * 0.4472", V_in_V_PP * 0.4472)
print_value("V_in_V_PP * 0.2425", V_in_V_PP * 0.2425)
print_value("V_in_V_PP * 0.0995", V_in_V_PP * 0.0995)
print_value("V_in_V_PP * 0.0499", V_in_V_PP * 0.0499)

# %% [markdown]
# 주파수를 f (실험) 값으로 변경시켜가면서, 표를 완성하라.

# %% [markdown]
# | f (실험) (Hz) | f (예시)      | f (이론)      | A_V_abs (이론) | 출력 진폭 (이론) | 출력 진폭 (예시값) | 출력 진폭 (측정값) (V_PP) |
# |---------------|---------------|---------------|----------------|------------------|--------------------|---------------------------|
# | ??            | 88            | 0.1 f_0       | 0.9950         | 3.9800           | 3.92               | ??                        |
# | ??            | 440           | 0.5 f_0       | 0.8944         | 3.5776           | 3.48               | ??                        |
# | ??            | 880           |     f_0       | 0.7071         | 2.8284           | 2.8284             | ??                        |
# | ??            | 1.76k         |   2 f_0       | 0.4472         | 1.7888           | 1.78               | ??                        |
# | ??            | 3.52k         |   4 f_0       | 0.2425         | 0.9700           | 1.0                | ??                        |
# | ??            | 8.8k          |  10 f_0       | 0.0995         | 0.3980           | 0.424              | ??                        |
# | ??            | 17.6k         |  20 f_0       | 0.0499         | 0.1996           | 0.224              | ??                        |

# %% [markdown]
# 크기에 대한 주파수응답을 그리시오.

# %%
f_Hz =   [    ??,    ??,    ??,    ??,    ??,    ??,    ??]
V_V_PP = [    ??,    ??,    ??,    ??,    ??,    ??,    ??]

# %%
f_Hz = np.array(f_Hz)
V_V_PP = np.array(V_V_PP)

# %%
# 주파수 - 진폭 선형 스케일
plt.xlabel('f_Hz')
plt.ylabel('V_V_PP')
plt.axhline(0, color='black')
plt.axvline(0, color='black')
# plt.xlim(-1000, 20000)
# plt.ylim(-0.3, 6.0)
plt.plot(f_Hz, V_V_PP, 'b.-')
plt.grid(True)
plt.show()

# %%
# 주파수 - 진폭 로그 스케일
# 첫 점을 기준 dB
f_log = np.log10(f_Hz)
V_ref = V_V_PP[0]
V_dB  = 20 * np.log10(V_V_PP / V_ref)

# 필터를 적용해 근사화
f_log_approx = savgol_filter(f_log, 5, 2)
V_dB_approx = savgol_filter(V_dB, 5, 2)

plt.xlabel('log10(f_Hz)')
plt.ylabel('Magnitude (V_dB re V_ref)')
plt.plot(f_log_approx, V_dB_approx, 'ro-')
plt.plot(f_log, V_dB, 'b.-')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 실험06 1차 HPF인 RC회로

# %% [markdown]
# #### 실험06-01 차단주파수를 찾는다.

# %% [markdown]
# 실험02의 회로가 1차 HPF 회로이다.

# %% [markdown]
# 입력 v_i 에 정현파를 인가하자 (파형발생기를 이용)
#
# * 주파수: 1 kHz
# * 크기: 4 V_PP

# %% [markdown]
# 진폭이 입력전압 크기의 $ 1 / \sqrt{2} $ 배가 되는 주파수를 찾는다.

# %%
V_in_V_PP = 4
V_cutoff_V_PP = V_in_V_PP / np.sqrt(2)
print_value("V_cutoff_V_PP", V_cutoff_V_PP)

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch07_05_ep06_01_result_plot.png", width=700)

# %% [markdown]
# 측정 결과를 기록한다.

# %% [markdown]
# |                       | 측정값          | 예시값          |
# |-----------------------|-----------------|-----------------|
# | 차단 주파수 f_0 (kHz) | ??              | 18              |

# %% [markdown]
# #### 실험06-02 주파수응답

# %% [markdown]
# f (실험) 값을 구한다.

# %%
f_0 = ??

# %%
print_value("0.01 * f_0", 0.01 * f_0) 
print_value(" 0.1 * f_0",  0.1 * f_0) 
print_value(" 0.2 * f_0",  0.2 * f_0) 
print_value(" 0.5 * f_0",  0.5 * f_0) 
print_value("       f_0",        f_0) 
print_value("   2 * f_0",    2 * f_0) 
print_value("   3 * f_0",    3 * f_0) 
print_value("   5 * f_0",    5 * f_0) 
print_value("  10 * f_0",   10 * f_0)

# %% [markdown]
# 출력 진폭 (이론)값은 다음과 같이 계산할 수 있다.
# * 출력 진폭 (이론)값: A_V_abs * 입력 진폭 (V_PP)

# %%
V_in_V_PP = 4
print_value("0.01   * V_in_V_PP", 0.01   * V_in_V_PP)
print_value("0.0995 * V_in_V_PP", 0.0995 * V_in_V_PP)
print_value("0.1961 * V_in_V_PP", 0.1961 * V_in_V_PP)
print_value("0.4472 * V_in_V_PP", 0.4472 * V_in_V_PP)
print_value("0.7071 * V_in_V_PP", 0.7071 * V_in_V_PP)
print_value("0.8944 * V_in_V_PP", 0.8944 * V_in_V_PP)
print_value("0.9487 * V_in_V_PP", 0.9487 * V_in_V_PP)
print_value("0.98   * V_in_V_PP", 0.98   * V_in_V_PP)
print_value("0.995  * V_in_V_PP", 0.995  * V_in_V_PP)

# %% [markdown]
# 주파수를 f (실험) 값으로 변경시켜가면서, 표를 완성하라.

# %% [markdown]
# | f (실험) (Hz) | f (예시)      | f (이론)      | A_V_abs (이론) | 출력 진폭 (이론) | 출력 진폭 (예시값) | 출력 진폭 (측정값) (V_PP) |
# |---------------|---------------|---------------|----------------|------------------|--------------------|---------------------------|
# | ??            | 180           | 0.01 f_0      | 0.01           | 0.04             | 0.0432             | ??                        |
# | ??            | 1.8k          |  0.1 f_0      | 0.0995         | 0.398            | 0.42               | ??                        |
# | ??            | 3.6k          |  0.2 f_0      | 0.1961         | 0.7844           | 0.824              | ??                        |
# | ??            | 9k            |  0.5 f_0      | 0.4472         | 1.7888           | 1.84               | ??                        |
# | ??            | 18k           |      f_0      | 0.7071         | 2.8284           | 2.82               | ??                        |
# | ??            | 36k           |    2 f_0      | 0.8944         | 3.5776           | 3.44               | ??                        |
# | ??            | 54k           |    3 f_0      | 0.9487         | 3.7948           | 3.64               | ??                        |
# | ??            | 90k           |    5 f_0      | 0.98           | 3.92             | 3.8                | ??                        |
# | ??            | 180k          |   10 f_0      | 0.995          | 3.98             | 3.84               | ??                        |

# %% [markdown]
# 크기에 대한 주파수응답을 그리시오.

# %%
f_Hz =   [     ??,     ??,     ??,      ??,    ??,     ??,     ??,     ??,     ??]
V_V_PP = [     ??,     ??,     ??,      ??,    ??,     ??,     ??,     ??,     ??]

# %%
f_Hz = np.array(f_Hz)
V_V_PP = np.array(V_V_PP)

# %%
# 주파수 - 진폭 선형 스케일
plt.xlabel('f_Hz')
plt.ylabel('V_V_PP')
plt.axhline(0, color='black')
plt.axvline(0, color='black')
# plt.xlim(-1000, 20000)
# plt.ylim(-0.3, 6.0)
plt.plot(f_Hz, V_V_PP, 'b.-')
plt.grid(True)
plt.show()

# %%
# 주파수 - 진폭 로그 스케일
# 첫 점을 기준 dB
f_log = np.log10(f_Hz)
V_ref = V_V_PP[0]
V_dB  = 20 * np.log10(V_V_PP / V_ref)

# 필터를 적용해 근사화
f_log_approx = savgol_filter(f_log, 5, 2)
V_dB_approx = savgol_filter(V_dB, 5, 2)

plt.xlabel('log10(f_Hz)')
plt.ylabel('Magnitude (V_dB re V_ref)')
plt.plot(f_log_approx, V_dB_approx, 'ro-')
plt.plot(f_log, V_dB, 'b.-')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 실험07 능동필터 : 1차 LPF

# %% [markdown]
# #### 실험07-01 회로의 구성

# %% [markdown]
# 다음 회로를 만들어보자.

# %%
display_image("./images/ch07_05_ep07_01_circuit.png", width=600)

# %% [markdown]
# f_0 를 미리 계산한다.

# %%
C_F = 0.015 / 1000000
R_2_Ohm = 10 * 1000

f_0_Hz = 1 / (2 * np.pi * C_F * R_2_Ohm)

f_0_Hz = round(f_0_Hz, 3)
print_value("f_0_Hz", f_0_Hz)

# %% [markdown]
# 최대 이득을 미리 계산한다.

# %%
R_1_Ohm = 1 * 1000
R_2_Ohm = 10 * 1000

A_V_abs_max = R_2_Ohm / R_1_Ohm

A_V_abs_max = round(A_V_abs_max, 0)
print_value("A_V_abs_max", A_V_abs_max)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch07_07_ep03_01_circuit_hardware.png", width=700)

# %% [markdown]
# #### 실험07-02 최대진폭을 찾는다.

# %% [markdown]
# 입력 v_i 에 정현파를 인가하자 (파형발생기를 이용)
#
# * 주파수: 1 kHz
# * 크기: 1 V_PP

# %% [markdown]
# 커패시터를 제거하고, 출력진폭을 구한다.

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch07_05_ep07_02_result_plot.png", width=700)

# %% [markdown]
# 측정 결과를 기록한다.

# %% [markdown]
# |                       | 측정값          | 예시값          |
# |-----------------------|-----------------|-----------------|
# | 출력의 진폭     (Vpp) | ??              | 9.52            |

# %% [markdown]
# #### 실험07-03 차단주파수를 찾는다.

# %% [markdown]
# 출력 진폭 크기의 $ 1 / \sqrt{2} $ 배 값을 계산한다.

# %%
V_out_max_V_PP = ??

# %%
V_cutoff_V_PP = V_out_max_V_PP / np.sqrt(2)
print_value("V_cutoff_V_PP", V_cutoff_V_PP)

# %% [markdown]
# 커패시터 부분을 원위치하고, 출력 진폭이 최대 출력 진폭 크기의 $ 1 / \sqrt{2} $ 배가 되는 주파수를 찾는다.

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch07_05_ep07_03_result_plot.png", width=700)

# %% [markdown]
# 측정 결과를 기록한다.

# %% [markdown]
# |                       | 측정값          | 예시값          |
# |-----------------------|-----------------|-----------------|
# | 차단 주파수 f_0 (kHz) | ??              | 1.04            |

# %% [markdown]
# #### 실험07-04 주파수응답

# %% [markdown]
# f (실험) 값을 구한다.

# %%
f_0 = ??

# %%
print_value("0.1 * f_0", 0.1 * f_0)
print_value("0.5 * f_0", 0.5 * f_0)
print_value("      f_0",       f_0)
print_value("  2 * f_0",   2 * f_0)
print_value("  4 * f_0",   4 * f_0)
print_value(" 10 * f_0",  10 * f_0)
print_value(" 20 * f_0",  20 * f_0)

# %% [markdown]
# 출력 진폭 (이론)값을 구한다.
# * 출력 진폭 이론값: A_V_abs * 출력 최대 진폭 (V_PP)

# %%
V_out_max_V_PP = ??

# %%
print_value("0.995  * V_out_max_V_PP", 0.995  * V_out_max_V_PP)
print_value("0.8944 * V_out_max_V_PP", 0.8944 * V_out_max_V_PP)
print_value("0.7071 * V_out_max_V_PP", 0.7071 * V_out_max_V_PP)
print_value("0.4472 * V_out_max_V_PP", 0.4472 * V_out_max_V_PP)
print_value("0.2425 * V_out_max_V_PP", 0.2425 * V_out_max_V_PP)
print_value("0.0995 * V_out_max_V_PP", 0.0995 * V_out_max_V_PP)
print_value("0.0499 * V_out_max_V_PP", 0.0499 * V_out_max_V_PP)

# %% [markdown]
# 주파수를 f (실험) 값으로 변경시켜가면서, 표를 완성하라.

# %% [markdown]
# | f (실험)      | f (예시)      | f (이론)      | A_V_abs (이론) | 출력 진폭 (이론) | 출력 진폭 (예시값) | 출력 진폭 (측정값) |
# |---------------|---------------|---------------|----------------|------------------|--------------------|--------------------|
# | ??            | 104            | 0.1 f_0      | 0.995          | ??               | 9.44               | ??                 |
# | ??            | 520            | 0.5 f_0      | 0.8944         | ??               | 8.48               | ??                 |
# | ??            | 1.04k          |     f_0      | 0.7071         | ??               | 6.72               | ??                 |
# | ??            | 2.08k          |   2 f_0      | 0.4472         | ??               | 4.32               | ??                 |
# | ??            | 4.16k          |   4 f_0      | 0.2425         | ??               | 2.36               | ??                 |
# | ??            | 10.4k          |  10 f_0      | 0.0995         | ??               | 0.968              | ??                 |
# | ??            | 20.8k          |  20 f_0      | 0.0499         | ??               | 0.479              | ??                 |

# %% [markdown]
# 크기에 대한 주파수응답을 그리시오.

# %%
f_Hz =   [    ??,    ??,    ??,    ??,    ??,    ??,    ??]
V_V_PP = [    ??,    ??,    ??,    ??,    ??,    ??,    ??]

# %%
f_Hz = np.array(f_Hz)
V_V_PP = np.array(V_V_PP)

# %%
# 주파수 - 진폭 선형 스케일
plt.xlabel('f_Hz')
plt.ylabel('V_V_PP')
plt.axhline(0, color='black')
plt.axvline(0, color='black')
# plt.xlim(-1000, 20000)
# plt.ylim(-0.3, 6.0)
plt.plot(f_Hz, V_V_PP, 'b.-')
plt.grid(True)
plt.show()

# %%
# 주파수 - 진폭 로그 스케일
# 첫 점을 기준 dB
f_log = np.log10(f_Hz)
V_ref = V_V_PP[0]
V_dB  = 20 * np.log10(V_V_PP / V_ref)

# 필터를 적용해 근사화
f_log_approx = savgol_filter(f_log, 5, 2)
V_dB_approx = savgol_filter(V_dB, 5, 2)

plt.xlabel('log10(f_Hz)')
plt.ylabel('Magnitude (V_dB re V_ref)')
plt.plot(f_log_approx, V_dB_approx, 'ro-')
plt.plot(f_log, V_dB, 'b.-')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 실험08 고주파수 노이즈제거

# %% [markdown]
# #### 실험08-01 신호의 구성

# %% [markdown]
# 실험07의 회로를 그대로 사용한다.

# %% [markdown]
# 두 개의 신호를 만들자 (파형발생기)
#
# * 채널1은 신호이고, 채널2는 고주파의 노이즈신호로 본다.
#     + 채널1: 1kHz, 1Vpp
#     + 채널2: 20kHz, 0.5Vpp

# %% [markdown]
# 두 신호를 실효값으로 계산해 둔다.

# %%
V_1_V_PP = 1

V_1_RMS = V_1_V_PP / (2 * np.sqrt(2))
print_value("V_1_RMS", V_1_RMS)
V_1_RMS_dB = 20 * np.log10(V_1_RMS)
print_value("V_1_RMS_dB", V_1_RMS_dB)

V_2_V_PP = 0.5

V_2_RMS = V_2_V_PP / (2 * np.sqrt(2))
print_value("V_2_RMS", V_2_RMS)
V_2_RMS_dB = 20 * np.log10(V_2_RMS)
print_value("V_2_RMS_dB", V_2_RMS_dB)

# %% [markdown]
# 두 신호를 중첩한다.
#
# * 파형발생기 > 채널2버튼 > More > Dual Channel > Combine > CH1를 누른다.

# %%
display_image("./images/ch07_05_ep08_01_input_signal.png", width=800)

# %% [markdown]
# #### 실험08-02 노이즈의 제거

# %% [markdown]
# 파형 발생기의 CH2를 회로에 연결한다.

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch07_05_ep08_02_result_plot.png", width=700)

# %% [markdown]
# * [퀴즈] 파형이 불안정하면, 어떻게 하면 안정화가 될까?
#     + 트리거소스를 변경?
#     + 트리거커플링을 변경?

# %% [markdown]
# ??

# %% [markdown]
# * [결과] 노이즈성분(20kHz)이 완전히 제거되지 않는다.

# %% [markdown]
# #### 실험08-03 입력신호의 주파수성분을 분석

# %% [markdown]
# FFT를 이용한다.

# %% [markdown]
# 먼저, 입력신호(채널1)에 대하여 주파수성분을 분석해보자.

# %% [markdown]
# FFT 계산을 위한 충분한 정보를 전달하기 위해 수평스케일을 다음과 같이 조정한다.
#
# * 10 ms/div

# %% [markdown]
# FFT를 실행한다.
#
# * M(Math) 메뉴버튼을 누르고, ‘FFT’에 해당하는 하단베젤메뉴를 누른다.
# * 화면에는 빨간색의 진폭스펙트럼이 나타날 것이다.
#     + 채널2 파형위에 진폭스펙트럼이 덮혀져 나타나기 때문에 지금은 잘 안 보일 수 있다.
# * [수직유닛]을 선형 RMS로 변경한다.

# %%
display_image("./data/ch07_05_ep08_03_result_plot.png", width=700)

# %% [markdown]
# Nyquist 주파수
#
# * 왼쪽 아래구석에 Nyquist 주파수가 나타난다. (현재는 26.04 kHz)
# * 이값은 수평스케일 계수값에 연동된다. (현재는 10ms/div)
# * 주의 : 이값이 측정하고자하는 신호의 주파수(20kHz)보다 커야한다!!!

# %% [markdown]
# 진폭스펙트럼만 보이게 하자
#
# * 입력신호와 진폭스펙트럼이 겹쳐서 나오면, 분석이 불편하다.
# * 채널1의 파형을 없애자 : Menu ‘1’버튼을 2번 누른다.
# * 채널2의 파형을 없애자 : Menu ‘2’버튼을 2번 누른다.

# %%
display_image("./data/ch07_05_ep08_03_result_plot_fft.png", width=700)

# %% [markdown]
# 진폭스펙트럼을 분석해보자.
#
# * 비연동식커서를 이용하여, 주파수성분을 분석한다.

# %%
display_image("./data/ch07_05_ep08_03_result_plot_fft_cursor.png", width=700)

# %% [markdown]
# 측정 결과를 기록한다.

# %% [markdown]
# * 첫 번째 성분
#
# |                      | 측정값          | 예시값          | 이론값          |
# |----------------------|-----------------|-----------------|-----------------|
# | 주파수 (kHz)         | ??              | 1               | 1               |
# | 크기 (V_RMS)         | ??              | 0.344           |  0.354          |
#
# * 두 번째 성분
#
# |                      | 측정값          | 예시값          | 이론값          |
# |----------------------|-----------------|-----------------|-----------------|
# | 주파수 (kHz)         | ??              | 20              | 20              |
# | 크기 (V_RMS)         | ??              | 0.172           | 0.177           |

# %% [markdown]
# #### 실험08-04 제거된 정도를 측정해보자

# %% [markdown]
# 출력신호(채널2)에 대하여 주파수성분을 분석해보자.

# %% [markdown]
# [FFT소스]를 채널2로 변경한다.

# %%
display_image("./data/ch07_05_ep08_04_result_plot_fft.png", width=700)

# %% [markdown]
# 진폭스펙트럼을 분석해보자.
#
# * 비연동식커서를 이용하여, 주파수성분을 분석한다.

# %%
display_image("./data/ch07_05_ep08_04_result_plot_fft_cursor.png", width=700)

# %% [markdown]
# * 첫 번째 성분
#
# |                      | 측정값          | 예시값          |
# |----------------------|-----------------|-----------------|
# | 주파수 (kHz)         | ??              | 1               |
# | 크기 (V_RMS)         | ??              | 2.44            |
#
# * 두 번째 성분
#
# |                      | 측정값          | 예시값          |
# |----------------------|-----------------|-----------------|
# | 주파수 (kHz)         | ??              | 20              |
# | 크기 (V_RMS)         | ??              | 측정 불가       |

# %% [markdown]
# * [결과] 노이즈성분(20kHz)의 크기가 너무 작아져서, 측정이 불가능하다.
#     + 이런 경우에 해결책이 바로 “로그”이다.

# %% [markdown]
# [수직유닛]을 dBV로 변경한다.

# %%
display_image("./data/ch07_05_ep08_04_result_fft_db_plot.png", width=700)

# %% [markdown]
# 진폭스펙트럼을 분석해보자.
#
# * 비연동식커서를 이용하여, 주파수성분을 분석한다.

# %% [markdown]
# 진폭스펙트럼을 분석해보자.
#
# * 비연동식커서를 이용하여, 주파수성분을 분석한다.

# %%
display_image("./data/ch07_05_ep08_04_result_fft_db_plot_cursor.png", width=700)

# %% [markdown]
# * 첫 번째 성분
#
# |                      | 측정값          | 예시값          |
# |----------------------|-----------------|-----------------|
# | 주파수 (kHz)         | ??              | 1               |
# | 크기 (dB)            | ??              | 8.8             |
#
# * 두 번째 성분
#
# |                      | 측정값          | 예시값          |
# |----------------------|-----------------|-----------------|
# | 주파수 (kHz)         | ??              | 20              |
# | 크기 (dB)            | ??              | -20             |

# %% [markdown]
# dB값을 실효값으로 변경해보자.

# %%
V_CH1_dB = ??
V_CH2_dB = ??

# %%
V_CH1_RMS = pow(10, V_CH1_dB / 20)
print_value("V_CH1_RMS", V_CH1_RMS)
V_CH2_RMS = pow(10, V_CH2_dB / 20)
print_value("V_CH2_RMS", V_CH2_RMS)

# %% [markdown]
# 입력측 노이즈 성분 V_RMS 값과 출력측 노이즈 성분 V_RMS 값을 비교해본다.

# %% [markdown]
# 노이즈 성분이 ?? 에서 ?? 으로 줄어들었다. (LPF의 역할)

# %% [markdown]
# * [결론] 선형스케일로 측정이 불가능한 것이 dB스케일로는 측정이 가능하였다.

# %% [markdown]
# ### 실험09 능동필터 : 1차 HPF

# %% [markdown]
# #### 실험09-01 회로의 구성

# %% [markdown]
# 다음 회로를 만들어보자.

# %%
display_image("./images/ch07_05_ep09_01_circuit.png", width=600)

# %% [markdown]
# f_0 를 미리 계산한다.

# %%
C_F = 0.015 / 1000000
R_1_Ohm = 1 * 1000

f_0_Hz = 1 / (2 * np.pi * C_F * R_1_Ohm)

f_0_kHz = round(f_0_Hz / 1000., 1)
print_value("f_0_kHz", f_0_kHz)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch07_05_ep09_01_circuit_hardware.png", width=700)

# %% [markdown]
# #### 실험09-02 최대진폭을 찾는다.

# %% [markdown]
# 입력 v_i 에 정현파를 인가하자 (파형발생기를 이용)
#
# * 주파수: 1 kHz
# * 크기: 1 V_PP

# %% [markdown]
# 커패시터를 단락하고, 출력진폭을 구한다.

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch07_05_ep09_02_result_plot.png", width=700)

# %% [markdown]
# 측정 결과를 기록한다.

# %% [markdown]
# |                       | 측정값          | 예시값          |
# |-----------------------|-----------------|-----------------|
# | 출력의 진폭     (Vpp) | ??              | 9.6             |

# %% [markdown]
# #### 실험09-03 차단주파수를 찾는다.

# %% [markdown]
# 출력 진폭 크기의 $ 1 / \sqrt{2} $ 배 값을 계산한다.

# %%
V_out_max_V_PP = ??

# %%
V_cutoff_V_PP = V_out_max_V_PP / np.sqrt(2)
print_value("V_cutoff_V_PP", V_cutoff_V_PP)

# %% [markdown]
# 커패시터 부분을 원위치하고, 출력 진폭이 최대 출력 진폭 크기의 $ 1 / \sqrt{2} $ 배가 되는 주파수를 찾는다.

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch07_05_ep09_03_result_plot.png", width=700)

# %% [markdown]
# * [퀴즈] 파형이 불안정하면, 어떻게 하면 안정화가 될까?
#     + 트리거소스를 변경?
#     + 트리거커플링을 변경?

# %% [markdown]
# ??

# %% [markdown]
# 측정 결과를 기록한다.

# %% [markdown]
# |                       | 측정값          | 예시값          |
# |-----------------------|-----------------|-----------------|
# | 차단 주파수 f_0 (kHz) | ??              | 9.4             |

# %% [markdown]
# #### 실험09-04 주파수응답

# %% [markdown]
# f (실험) 값을 구한다.

# %%
f_0 = ??

# %%
print_value("0.01 * f_0", 0.01 * f_0)
print_value(" 0.1 * f_0",  0.1 * f_0)
print_value(" 0.2 * f_0",  0.2 * f_0)
print_value(" 0.5 * f_0",  0.5 * f_0)
print_value("       f_0",        f_0)
print_value("   2 * f_0",    2 * f_0)
print_value("   3 * f_0",    3 * f_0)
print_value("   5 * f_0",    5 * f_0)
print_value("  10 * f_0",   10 * f_0)

# %% [markdown]
# 출력 진폭 (이론)값을 구한다.
# * 출력 진폭 이론값: A_V_abs * 출력 최대 진폭 (V_PP)

# %%
V_out_max_V_PP = ??

# %%
print_value("0.01   * V_out_max_V_PP", 0.01   * V_out_max_V_PP)
print_value("0.0995 * V_out_max_V_PP", 0.0995 * V_out_max_V_PP)
print_value("0.1961 * V_out_max_V_PP", 0.1961 * V_out_max_V_PP)
print_value("0.4472 * V_out_max_V_PP", 0.4472 * V_out_max_V_PP)
print_value("0.7071 * V_out_max_V_PP", 0.7071 * V_out_max_V_PP)
print_value("0.8944 * V_out_max_V_PP", 0.8944 * V_out_max_V_PP)
print_value("0.9487 * V_out_max_V_PP", 0.9487 * V_out_max_V_PP)
print_value("0.98   * V_out_max_V_PP", 0.98   * V_out_max_V_PP)
print_value("0.995  * V_out_max_V_PP", 0.995  * V_out_max_V_PP)

# %% [markdown]
# 주파수를 증가시키면서, 표를 완성하라.
#
# * 출력 진폭 이론값: A_V_abs * 입력 진폭 (V_PP)

# %% [markdown]
# | f (실험)      | f (예시)      | f (이론)      | A_V_abs (이론) | 출력 진폭 (이론) | 출력 진폭 (예시값) | 출력 진폭 (측정값) |
# |---------------|---------------|---------------|----------------|------------------|--------------------|--------------------|
# | ??            | 94            | 0.01 f_0      | 0.01           | ??               | 92.8m              | ??                 |
# | ??            | 940           |  0.1 f_0      | 0.0995         | ??               | 928m               | ??                 |
# | ??            | 1.88k         |  0.2 f_0      | 0.1961         | ??               | 1.84               | ??                 |
# | ??            | 4.7k          |  0.5 f_0      | 0.4472         | ??               | 4.24               | ??                 |
# | ??            | 9.4k          |      f_0      | 0.7071         | ??               | 6.8                | ??                 |
# | ??            | 18.8k         |    2 f_0      | 0.8944         | ??               | 8.96               | ??                 |
# | ??            | 28.2k         |    3 f_0      | 0.9487         | ??               | 9.52               | ??                 |
# | ??            | 47k           |    5 f_0      | 0.98           | ??               | 6.72               | ??                 |
# | ??            | 94k           |   10 f_0      | 0.995          | ??               | 3.6                | ??                 |

# %% [markdown]
# 크기에 대한 주파수응답을 그리시오.

# %%
f_Hz =   [    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??]
V_V_PP = [    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??]

# %%
f_Hz = np.array(f_Hz)
V_V_PP = np.array(V_V_PP)

# %%
# 주파수 - 진폭 선형 스케일
plt.xlabel('f_Hz')
plt.ylabel('V_V_PP')
plt.axhline(0, color='black')
plt.axvline(0, color='black')
# plt.xlim(-1000, 20000)
# plt.ylim(-0.3, 6.0)
plt.plot(f_Hz, V_V_PP, 'b.-')
plt.grid(True)
plt.show()

# %%
# 주파수 - 진폭 로그 스케일
# 첫 점을 기준 dB
f_log = np.log10(f_Hz)
V_ref = V_V_PP[0]
V_dB  = 20 * np.log10(V_V_PP / V_ref)

# 필터를 적용해 근사화
f_log_approx = savgol_filter(f_log, 5, 2)
V_dB_approx = savgol_filter(V_dB, 5, 2)

plt.xlabel('log10(f_Hz)')
plt.ylabel('Magnitude (V_dB re V_ref)')
plt.plot(f_log_approx, V_dB_approx, 'ro-')
plt.plot(f_log, V_dB, 'b.-')
plt.grid(True)
plt.show()

# %% [markdown]
# * [결과] 주파수가 커지면서, 출력이 감소하였다. 그 원인은 무엇인가? (힌트는 5장)

# %% [markdown]
# ??

# %% [markdown]
# ### 실험10 저주파수 노이즈제거

# %% [markdown]
# #### 실험10-01 신호의 구성

# %% [markdown]
# 실험09의 회로를 그대로 사용한다.

# %% [markdown]
# 두 개의 신호를 만들자 (파형발생기)
#
# * 채널1은 신호이고, 채널2는 저주파의 노이즈신호로 본다.
#     + 채널1: 25kHz, 1Vpp
#     + 채널2: 100Hz, 0.5Vpp

# %% [markdown]
# 두 신호를 중첩한다.
#
# * 파형발생기 > 채널2버튼 > More > Dual Channel > Combine > CH1를 누른다.

# %% [markdown]
# #### 실험10-02 노이즈의 제거

# %% [markdown]
# 파형 발생기의 CH2를 회로에 연결한다.

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch07_05_ep10_02_result_plot.png", width=700)

# %% [markdown]
# * [퀴즈] 파형이 불안정하면, 어떻게 하면 안정화가 될까?
#     + 트리거소스를 변경?
#     + 트리거커플링을 변경?

# %% [markdown]
# ??

# %% [markdown]
# * [결과] 노이즈성분(100Hz)이 완전히 제거되었다.

# %% [markdown]
# 노이즈의 주파수를 증가시켜 본다.
#
# * 채널2의 주파수를 2kHz로 변경한다.

# %%
display_image("./data/ch07_05_ep10_02_result_2khz_plot.png", width=700)

# %% [markdown]
# * [결과] 노이즈성분(2kHz)이 완전히 제거되지 않는다.

# %% [markdown]
# ### 실험11 능동필터 : 2차 LPF

# %% [markdown]
# #### 실험11-01 회로의 구성

# %% [markdown]
# 다음 회로를 만들어보자.

# %%
display_image("./images/ch07_05_ep11_01_circuit.png", width=600)

# %% [markdown]
# f_0 를 미리 계산한다.

# %%
C_1_F = 0.015 / 1000000
R_2_Ohm = 10 * 1000

f_0_Hz = 1 / (2 * np.pi * C_1_F * R_2_Ohm)

f_0_Hz = round(f_0_Hz, 3)
print_value("f_0_Hz", f_0_Hz)

# %% [markdown]
# 최대 이득을 미리 계산한다.

# %%
R_A_Ohm = 1 * 1000
R_B_Ohm = 600

A_V_abs_max = 1 + R_B_Ohm / R_A_Ohm

A_V_abs_max = round(A_V_abs_max, 1)
print_value("A_V_abs_max", A_V_abs_max)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch07_05_ep11_01_circuit_hardware.png", width=700)

# %% [markdown]
# #### 실험11-02 주파수응답

# %% [markdown]
# 주파수를 증가시키면서, 표를 완성하라. (진폭은 1 V_PP)

# %% [markdown]
# | f (실험) (Hz) | 출력 진폭 (예시값) (V_PP) | 출력 진폭 (측정값) (V_PP) |
# |---------------|---------------------------|---------------------------|
# | 100           | 1.59                      | ??                        |
# | 200           | 1.59                      | ??                        |
# | 300           | 1.59                      | ??                        |
# | 400           | 1.57                      | ??                        |
# | 500           | 1.53                      | ??                        |
# | 600           | 1.47                      | ??                        |
# | 700           | 1.39                      | ??                        |
# | 800           | 1.29                      | ??                        |
# | 900           | 1.17                      | ??                        |
# | 1000          | 1.05                      | ??                        |
# | 2000          | 0.354                     | ??                        |
# | 3000          | 0.166                     | ??                        |
# | 4000          | 0.094                     | ??                        |
# | 5000          | 0.060                     | ??                        |
# | 6000          | 0.042                     | ??                        |
# | 7000          | 0.030                     | ??                        |
# | 8000          | 0.024                     | ??                        |
# | 9000          | 0.019                     | ??                        |
# | 10000         | 0.015                     | ??                        |

# %% [markdown]
# 크기에 대한 주파수응답을 그리시오.

# %%
f_Hz =   [     ??,     ??,     ??,     ??,     ??,     ??,     ??,     ??,     ??,     ??,     ??,     ??,     ??,     ??,     ??,     ??,     ??,     ??,     ??]
V_V_PP = [     ??,     ??,     ??,     ??,     ??,     ??,     ??,     ??,     ??,     ??,     ??,     ??,     ??,     ??,     ??,     ??,     ??,     ??,     ??]

# %%
f_Hz = np.array(f_Hz)
V_V_PP = np.array(V_V_PP)

# %%
# 주파수 - 진폭 선형 스케일
plt.xlabel('f_Hz')
plt.ylabel('V_V_PP')
plt.axhline(0, color='black')
plt.axvline(0, color='black')
# plt.xlim(-1000, 20000)
# plt.ylim(-0.3, 6.0)
plt.plot(f_Hz, V_V_PP, 'b.-')
plt.grid(True)
plt.show()

# %%
# 주파수 - 진폭 로그 스케일
# 첫 점을 기준 dB
f_log = np.log10(f_Hz)
V_ref = V_V_PP[0]
V_dB  = 20 * np.log10(V_V_PP / V_ref)

# 필터를 적용해 근사화
# f_log_approx = savgol_filter(f_log, 5, 2)
# V_dB_approx = savgol_filter(V_dB, 5, 2)

plt.xlabel('log10(f_Hz)')
plt.ylabel('Magnitude (V_dB re V_ref)')
# plt.plot(f_log_approx, V_dB_approx, 'ro-')
plt.plot(f_log, V_dB, 'b.-')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 실험12 고주파수 노이즈제거

# %% [markdown]
# #### 실험12-01 신호의 구성

# %% [markdown]
# 실험11의 회로를 그대로 사용한다.

# %% [markdown]
# 두 개의 신호를 만들자 (파형발생기)
#
# * 채널1은 신호이고, 채널2는 고주파의 노이즈신호로 본다.
#     + 채널1: 1kHz, 1Vpp
#     + 채널2: 20kHz, 0.5Vpp

# %% [markdown]
# 두 신호를 중첩한다.
#
# * 파형발생기 > 채널2버튼 > More > Dual Channel > Combine > CH1를 누른다.

# %% [markdown]
# #### 실험12-02 노이즈의 제거

# %% [markdown]
# 파형 발생기의 CH2를 회로에 연결한다.

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch07_05_ep12_02_result_plot.png", width=700)

# %% [markdown]
# * [퀴즈] 파형이 불안정하면, 어떻게 하면 안정화가 될까?
#     + 트리거소스를 변경?
#     + 트리거커플링을 변경?

# %% [markdown]
# ??

# %% [markdown]
# * [결과] 노이즈성분(20kHz)이 완전히 제거된다.
# * [비교] 1차 필터에서는 완전히 제거되지 않았다.

# %% [markdown]
# ### 실험13 능동필터 : 2차 HPF

# %% [markdown]
# #### 실험13-01 회로의 구성

# %% [markdown]
# 다음 회로를 만들어보자.

# %%
display_image("./images/ch07_05_ep13_01_circuit.png", width=600)

# %% [markdown]
# f_0 를 미리 계산한다.

# %%
C_1_F = 0.015 / 1000000
R_1_Ohm = 1 * 1000

f_0_Hz = 1 / (2 * np.pi * C_1_F * R_1_Ohm)

f_0_Hz = round(f_0_Hz, 3)
print_value("f_0_Hz", f_0_Hz)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch07_05_ep13_01_circuit_hardware.png", width=700)

# %% [markdown]
# #### 실험13-02 주파수응답

# %% [markdown]
# 주파수를 증가시키면서, 표를 완성하라. (진폭은 1 V_PP)

# %% [markdown]
# | f (실험) (Hz) | 출력 진폭 (예시값) (V_PP) | 출력 진폭 (측정값) (V_PP) |
# |---------------|---------------------------|---------------------------|
# |  1000         | 0.0184                    | ??                        |
# |  2000         |  0.072                    | ??                        |
# |  3000         |  0.156                    | ??                        |
# |  4000         |  0.276                    | ??                        |
# |  5000         |  0.412                    | ??                        |
# |  6000         |  0.572                    | ??                        |
# |  7000         |  0.728                    | ??                        |
# |  8000         |  0.896                    | ??                        |
# |  9000         |   1.03                    | ??                        |
# | 10000         |   1.15                    | ??                        |
# | 11000         |   1.23                    | ??                        |
# | 12000         |   1.32                    | ??                        |
# | 13000         |   1.36                    | ??                        |
# | 14000         |   1.39                    | ??                        |
# | 15000         |   1.42                    | ??                        |
# | 16000         |   1.46                    | ??                        |
# | 17000         |   1.47                    | ??                        |
# | 18000         |   1.48                    | ??                        |
# | 19000         |   1.49                    | ??                        |
# | 20000         |   1.50                    | ??                        |
# | 21000         |   1.50                    | ??                        |
# | 22000         |   1.50                    | ??                        |
# | 23000         |   1.52                    | ??                        |
# | 24000         |   1.52                    | ??                        |
# | 25000         |   1.52                    | ??                        |

# %% [markdown]
# 크기에 대한 주파수응답을 그리시오.

# %%
f_Hz =   [    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??]
V_V_PP = [    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??,    ??]

# %%
f_Hz = np.array(f_Hz)
V_V_PP = np.array(V_V_PP)

# %%
# 주파수 - 진폭 선형 스케일
plt.xlabel('f_Hz')
plt.ylabel('V_V_PP')
plt.axhline(0, color='black')
plt.axvline(0, color='black')
# plt.xlim(-1000, 20000)
# plt.ylim(-0.3, 6.0)
plt.plot(f_Hz, V_V_PP, 'b.-')
plt.grid(True)
plt.show()

# %%
# 주파수 - 진폭 로그 스케일
# 첫 점을 기준 dB
f_log = np.log10(f_Hz)
V_ref = V_V_PP[0]
V_dB  = 20 * np.log10(V_V_PP / V_ref)

# 필터를 적용해 근사화
# f_log_approx = savgol_filter(f_log, 5, 2)
# V_dB_approx = savgol_filter(V_dB, 5, 2)

plt.xlabel('log10(f_Hz)')
plt.ylabel('Magnitude (V_dB re V_ref)')
# plt.plot(f_log_approx, V_dB_approx, 'ro-')
plt.plot(f_log, V_dB, 'b.-')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 실험14 저주파수 노이즈제거

# %% [markdown]
# #### 실험14-01 신호의 구성

# %% [markdown]
# 실험13의 회로를 그대로 사용한다.

# %% [markdown]
# 두 개의 신호를 만들자 (파형발생기)
#
# * 채널1은 신호이고, 채널2는 저주파의 노이즈신호로 본다.
#     + 채널1: 25kHz, 1Vpp
#     + 채널2: 2kHz, 0.5Vpp

# %% [markdown]
# 두 신호를 중첩한다.
#
# * 파형발생기 > 채널2버튼 > More > Dual Channel > Combine > CH1를 누른다.

# %% [markdown]
# #### 실험14-02 노이즈의 제거

# %% [markdown]
# 파형 발생기의 CH2를 회로에 연결한다.

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch07_05_ep14_02_result_plot.png", width=700)

# %% [markdown]
# * [퀴즈] 파형이 불안정하면, 어떻게 하면 안정화가 될까?
#     + 트리거소스를 변경?
#     + 트리거커플링을 변경?

# %% [markdown]
# ??

# %% [markdown]
# * [결과] 노이즈성분(100Hz)이 완전히 제거되었다.
# * [비교] 1차 필터에서는 완전히 제거되지 않았다.
