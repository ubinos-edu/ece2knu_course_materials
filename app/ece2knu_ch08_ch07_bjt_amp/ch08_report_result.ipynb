# %% [markdown]
# # 08장 BJT 증폭기

# %% [markdown]
# * 이름: 홍길동
# * 학번: 2025123456
# * 조: 1

# %% [markdown]
# ## 공통 코드

# %%
import sys
from pathlib import Path

# common_dir = Path.cwd().parent / "ece2knu_common"
common_dir = Path.cwd()
sys.path.insert(0, str(common_dir))

from common import *

# %% [markdown]
# *******************************************************************************

# %% [markdown]
# ## 8.5 실험 내용

# %% [markdown]
# ### 실험01 beta 값의 측정

# %% [markdown]
# DM332의 DMM에는 트랜지스터의 beta 값의 측정하는 모드가 존재한다.
#
# 값의 다른 이름은 hFE이다.
#
# 왼쪽 밑에 해당 트랜지스터를 꼽고, 선택단자를 "NPN"으로 맞추면 hFE값(즉, beta 값)이 측정된다.

# %%
display_image("./images/ch08_05_ep01_01_circuit.png", width=700)

# %% [markdown]
# 같은 공장의 같은 생산라인에서 만들어진 트랜지스터라도, beta 값은 매우 다양하다.
#
# **여러 개를 측정하여 beta = 210 에 가까운 트랜지스터를 찾아 이후 실험에 사용한다.**

# %% [markdown]
# ### 실험02 비선형 전달특성을 가지는 증폭기

# %% [markdown]
# 다음 회로를 만들어보자.

# %%
display_image("./images/ch08_05_ep02_01_circuit.png", width=500)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch08_05_ep02_01_circuit_hardware.png", width=700)

# %% [markdown]
# 입력 v_i 에 다음 정현파를 인가하자 (파형발생기를 이용)
#
# * f = 1 kHz
# * 2 V_PP

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch08_05_ep02_01_result_plot.png", width=700)

# %% [markdown]
# * [결과] 바이어스가 잡혀있지 않기 때문에, 출력파형은 왜곡이 심하다.

# %% [markdown]
# 입력 v_i 에 다음 정현파를 인가하자 (파형발생기를 이용)
#
# * f = 50 Hz
# * 7 V_PP

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch08_05_ep02_02_result_plot.png", width=700)

# %% [markdown]
# XY 모드로 설정한다.

# %%
display_image("./data/ch08_05_ep02_02_result_plot_xy.png", width=700)

# %% [markdown]
# ### 실험03 CE증폭기1 회로의 동작점

# %% [markdown]
# #### 실험03-01 회로를 만든다.

# %% [markdown]
# 다음 회로를 만들어보자.

# %% [markdown]
# * 트랜지스터: 2N2222

# %%
display_image("./images/ch08_05_ep03_01_circuit.png", width=300)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch08_05_ep03_01_circuit_hardware.png", width=700)

# %% [markdown]
# DMM을 이용하여 V_CE 값을 측정하라.
#
# I_C 는 전류계를 사용하지 말고 다음과 같이 계산하라.

# %%
V_CE_V = ??

# %%
V_CC_V = 15
R_C_Ohm = 3000

I_C_mA = (V_CC_V - V_CE_V) / R_C_Ohm * 1000

print_value("I_C_mA", I_C_mA)

# %% [markdown]
# |                 | 해석         | 예시값       | 측정값       |
# |-----------------|--------------|--------------|--------------|
# | V_CE (V)        | 7.5          | 7.2          | ??           |
# | I_C (mA)        | 2.5          | 2.6          | ??           |

# %% [markdown]
# * 이 회로는 불안정하기 때문에 측정값이 계속 변동할 것이다.
#
# * [검토] 약간 포화영역으로 치우쳐있다. R_2 저항값을 작게 하면 차단영역쪽으로 보낼 수 있다.

# %% [markdown]
# R_2 저항을 3.9 kOhm 으로 교체해 다시 측정한다.

# %%
V_CE_V = ??

# %%
V_CC_V = 15
R_C_Ohm = 3000

I_C_mA = (V_CC_V - V_CE_V) / R_C_Ohm * 1000

print_value("I_C_mA", I_C_mA)

# %% [markdown]
# |                 | 예시값       | 측정값       |
# |-----------------|--------------|--------------|
# | V_CE (V)        | 14.36        | ??           |
# | I_C (mA)        | 0.213        | ??           |

# %% [markdown]
# #### 실험03-02 동작점을 정중앙으로 만든다.

# %% [markdown]
# 다음과 같이 CE증폭기1 회로를 변경한다.

# %%
display_image("./images/ch08_05_ep03_02_circuit.png", width=300)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch08_05_ep03_02_circuit_hardware.png", width=700)

# %% [markdown]
# 2 kOhm 가변저항을 조절하여 V_CEQ = 7.5 V가 되도록 만든다.

# %% [markdown]
# #### 실험03-03 온도의 변화에 대한 민감도 실험

# %% [markdown]
# 온도의 변화에 대한 실험을 한다.
# * 트랜지스터를 손으로 10초 동안 잡는다.

# %% [markdown]
# |                 | 예시값       | 측정값       |
# |-----------------|--------------|--------------|
# | V_CE (V)        | 6.65         | ??           |

# %% [markdown]
# * [검토] 온도가 올라가면 => I_C가 증가하고 => V_CE 는 감소한다.

# %% [markdown]
# 손을 놓으면 V_CE 가 서서히 원상복구된다.

# %% [markdown]
# 헤어드라이기를 이용하여 강력하게 열을 전달해보자.
# * 헤어드라이기를 5초 동안 이용한다.
# * V_CE 가 강력하게 감소하는 것만 확인한다.

# %% [markdown]
# |                 | 예시값       | 측정값       |
# |-----------------|--------------|--------------|
# | V_CE (V)        | 4            | ??           |

# %% [markdown]
# 다음 실험을 위하여 다른 트랜지스터로 교체하고, 가변저항을 조절하여 다시 V_CEQ = 7.5 V가 되도록 만든다.
# * 원상복구되려면 오래 기다려야한다.

# %% [markdown]
# ### 실험04 CE증폭기1 회로의 교류증폭

# %% [markdown]
# #### 실험03-01 회로를 만든다.

# %% [markdown]
# 다음 회로를 만들어보자.

# %%
display_image("./images/ch08_05_ep04_01_circuit.png", width=500)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch08_05_ep04_01_circuit_hardware.png", width=700)

# %% [markdown]
# 입력 v_i 에 다음 정현파를 인가하자 (파형발생기를 이용)
#
# * f = 1 kHz
# * 30 mV_PP

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %% [markdown]
# * 채널2의 직류전압성분을 제거하기 위하여, 채널2의 커플링을 AC모드로 변환한다.
# * 입력이 작다보니 CH1에는 노이즈의 영향이 커서 파형이 불안정하다. 그에 비해 CH2의 파형은 깨끗하다.
#     + => 트리거 소스를 CH2로 변경한다.

# %%
display_image("./data/ch08_05_ep04_01_result_plot.png", width=700)

# %% [markdown]
# 자동측정으로 출력의 Vpp를 측정한다.

# %% [markdown]
# |                 | 예시값       | 측정값       |
# |-----------------|--------------|--------------|
# | 출력의 V_PP     | 7.84         | ??           |

# %% [markdown]
# 이득을 계산한다.

# %%
V_out_V_PP = ??

# %%
V_in_V_PP = 0.030

A_v_abs = V_out_V_PP / V_in_V_PP

print_value("A_v_abs", A_v_abs)

# %% [markdown]
# |                 | 예시값       | 측정값       |
# |-----------------|--------------|--------------|
# | 이득            | 261          | ??           |

# %% [markdown]
# [검토] 이 증폭기의 특징 중의 하나가 이득이 매우 크다는 것이다.

# %% [markdown]
# #### 실험04-02 R_2 저항값의 변화에 대한 민감도 실험

# %% [markdown]
# 가변저항을 최대한 작게 만든다. (반시계방향으로 최대로 돌린다.)

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch08_05_ep04_02_1_result_plot.png", width=700)

# %% [markdown]
# V_CE 값을 측정하라.

# %% [markdown]
# |                 | 예시값       | 측정값       |
# |-----------------|--------------|--------------|
# | V_CE (V)        | 14.49        | ??           |

# %% [markdown]
# * V_CE가 크게 증가한다.
# * [검토] 회로가 차단영역으로 치우치면서 출력파형의 왜곡이 심하게 생긴다.

# %% [markdown]
# 가변저항을 최대한 크게 만든다. (시계방향으로 최대로 돌린다.)

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch08_05_ep04_02_2_result_plot.png", width=700)

# %% [markdown]
# V_CE 값을 측정하라.

# %% [markdown]
# |                 | 예시값       | 측정값       |
# |-----------------|--------------|--------------|
# | V_CE (V)        | 3.82         | ??           |

# %% [markdown]
# * V_CE 가 크게 감소한다.
# * [검토] 회로가 포화영역으로 치우치면서 출력파형의 왜곡이 심하게 생긴다.

# %% [markdown]
# 다음 실험을 위해 가변저항을 조절하여 다시 V_CEQ = 7.5 V 가 되도록 만든다.

# %% [markdown]
# #### 실험04-03 온도의 변화에 대한 민감도 실험

# %% [markdown]
# 헤어드라이기를 이용하여 강력하게 열을 전달해보자.

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch08_05_ep04_03_result_plot.png", width=700)

# %% [markdown]
# V_CE 값을 측정하라.

# %% [markdown]
# |                 | 예시값       | 측정값       |
# |-----------------|--------------|--------------|
# | V_CE (V)        | 4.8          | ??           |

# %% [markdown]
# * V_CE 가 크게 감소한다.
# * [검토] 회로가 포화영역으로 치우치면서 출력파형의 왜곡이 심하게 생긴다.

# %% [markdown]
# ### 실험05 CE증폭기2 회로의 동작점

# %% [markdown]
# #### 실험05-01 회로를 만든다.

# %% [markdown]
# 다음 회로를 만들어보자.

# %%
display_image("./images/ch08_05_ep05_01_circuit.png", width=500)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch08_05_ep05_01_circuit_hardware.png", width=700)

# %% [markdown]
# DMM을 이용하여 V_CE 값을 측정하라.
#
# I_C 는 전류계를 사용하지 말고 다음과 같이 계산하라.

# %%
V_CE_V = ??

# %%
V_CC_V = 15
R_C_Ohm = 3000
R_E_Ohm = 1000

I_C_mA = (V_CC_V - V_CE_V) / (R_C_Ohm + R_E_Ohm) * 1000

print_value("I_C_mA", I_C_mA)

# %% [markdown]
# |                 | 해석         | 예시값       | 측정값       |
# |-----------------|--------------|--------------|--------------|
# | V_CE (V)        | 7.362        | 7.36         | ??           |
# | I_C (mA)        | 1.91         | 1.909        | ??           |

# %% [markdown]
# #### 실험05-02 R_2 저항값의 변화에 대한 민감도 실험

# %% [markdown]
# R_2 저항을 20 kOhm 으로 교체해 다시 측정한다.

# %% [markdown]
# |                 | 해석         | 예시값       | 측정값       |
# |-----------------|--------------|--------------|--------------|
# | V_CE (V)        | 8.088        | 8.04         | ??           |

# %% [markdown]
# R_2 저항을 27 kOhm 으로 교체해 다시 측정한다.

# %% [markdown]
# |                 | 해석         | 예시값       | 측정값       |
# |-----------------|--------------|--------------|--------------|
# | V_CE (V)        | 5.674        | 5.82         | ??           |

# %% [markdown]
# 다음 실험을 위해 R_2 저항을 22 kOhm 으로 교체한다.

# %% [markdown]
# #### 실험05-03 온도의 변화에 대한 민감도 실험

# %% [markdown]
# 온도의 변화에 대한 실험을 한다.
# * 트랜지스터를 손으로 10초 동안 잡는다.

# %% [markdown]
# |                 | 예시값       | 측정값       |
# |-----------------|--------------|--------------|
# | V_CE (V)        | 7.31         | ??           |

# %% [markdown]
# * [검토] 온도가 올라가면 => I_C 가 증가하고 => V_CE 는 감소한다.
# * [검토] 증폭기1 회로에 비해, 큰 차이를 보이지 않는다.

# %% [markdown]
# 손을 놓으면 V_CE 가 서서히 원상복구된다.

# %% [markdown]
# 헤어드라이기를 이용하여 강력하게 열을 전달해보자.
# * 헤어드라이기를 5초 동안 이용한다.
# * V_CE 가 강력하게 감소하는 것만 확인한다.

# %% [markdown]
# |                 | 예시값       | 측정값       |
# |-----------------|--------------|--------------|
# | V_CE (V)        | 7.15         | ??           |

# %% [markdown]
# * [검토] 증폭기1 회로에 비해, 큰 차이를 보이지 않는다.

# %% [markdown]
# ### 실험06 CE증폭기2 회로의 교류증폭

# %% [markdown]
# #### 실험06-01 교류증폭 실험

# %% [markdown]
# 실험05의 CE증폭기2 회로를 그대로 사용한다.

# %% [markdown]
# 입력 v_i 에 다음 정현파를 인가하자 (파형발생기를 이용)
#
# * f = 1 kHz
# * 1 V_PP

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %% [markdown]
# * 채널2의 직류전압성분을 제거하기 위하여, 채널2의 커플링을 AC모드로 변환한다.

# %%
display_image("./data/ch08_05_ep06_01_result_plot.png", width=700)

# %% [markdown]
# 자동측정으로 출력의 Vpp를 측정한다.

# %% [markdown]
# |                 | 예시값       | 측정값       |
# |-----------------|--------------|--------------|
# | 출력의 V_PP     | 2.92         | ??           |

# %% [markdown]
# * [검토] 이 증폭기의 대략적인 전압이득은 A_V = - R_C / R_E = -3 이다.
#     + 위상이 반전되었으므로 이득은 음수값을 가진다.

# %% [markdown]
# #### 실험06-02 최대 입력전압

# %% [markdown]
# 입력전압의 크기를 키워보자!
#
# 입력을 V_PP = 4 V으로 하면, 출력파형에 왜곡이 생긴다.

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch08_05_ep06_02_1_result_plot.png", width=700)

# %% [markdown]
# 입력전압을 서서히 줄여서, 출력전압에 왜곡이 없는 때를 찾아라.

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch08_05_ep06_02_2_result_plot.png", width=700)

# %% [markdown]
# 왜곡이 없어지는 입력 전압을 기록한다.

# %% [markdown]
# ?? V_PP

# %% [markdown]
# #### 실험06-03 민감도 실험

# %% [markdown]
# R_2 저항을 20 kOhm 으로 대신한다.

# %%
display_image("./data/ch08_05_ep06_03_1_result_plot.png", width=700)

# %% [markdown]
# * [결과] 동작점이 차단영역쪽으로 약간 이동한다. 출력파형의 왜곡을 거의 찾을 수 없다.

# %% [markdown]
# R_2 저항을 27 kOhm 으로 대신한다.

# %%
display_image("./data/ch08_05_ep06_03_2_result_plot.png", width=700)

# %% [markdown]
# * [결과] 동작점이 포화영역쪽으로 약간 이동한다. 동작점의 이동의 영향으로 출력파형에 왜곡이 나타난다.

# %% [markdown]
# 왜곡이 일어나지 않도록 입력전압의 크기를 줄여보자.

# %%
display_image("./data/ch08_05_ep06_03_3_result_plot.png", width=700)

# %% [markdown]
# * [결과] 진폭을 2.8V로 감소했을 때, 왜곡이 일어나지 않는다.
# * [결론] 바이어스가 제대로 잡혀있지 않으면, 출력의 크기에 제한이 생긴다.

# %% [markdown]
# 다음 실험을 위해, R_2 저항을 22 kOhm 저항으로 복귀한다.

# %% [markdown]
# ### 실험07 부하효과의 심각성을 보자.

# %% [markdown]
# #### 실험07-01 부하효과

# %% [markdown]
# 입력 v_i 에 다음 정현파를 인가하자 (파형발생기를 이용)
#
# * f = 1 kHz
# * 2 V_PP

# %% [markdown]
# 자동측정으로 출력의 V_PP 를 측정한다. 여기까지는 실험 6의 결과이다.

# %%
display_image("./data/ch08_05_ep07_01_1_result_plot.png", width=700)

# %% [markdown]
# 다음과 같이 부하저항 200 Ohm을 연결한다.

# %%
display_image("./images/ch08_05_ep07_01_2_circuit.png", width=500)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch08_05_ep07_01_2_circuit_hardware.png", width=700)

# %% [markdown]
# 출력의 V_PP 를 측정한다.

# %%
display_image("./data/ch08_05_ep07_01_2_result_plot.png", width=700)

# %% [markdown]
# |                 | 예시값 (V_PP)   | 측정값 (V_PP)    |
# |-----------------|-----------------|------------------|
# | 무부하          | 5.96            | ??               |
# | 부하            | 0.36            | ??               |

# %% [markdown]
# * [결과] 심각한 부하효과가 나타난다.

# %% [markdown]
# #### 실험07-02 출력저항 R_O의 측정

# %% [markdown]
# 디음과 같이 부하저항 200 Ohm을 제거하고, 다음과 같이 5 kOhm 가변저항을 연결한다.

# %%
display_image("./images/ch08_05_ep07_02_1_circuit.png", width=500)

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch08_05_ep07_02_1_circuit_hardware.png", width=700)

# %% [markdown]
# 저항값을 가변하여서 출력전압이 무부하일 때의 반값이 되도록 한다.

# %%
V_out_no_load_V_PP = ??

# %%
V_out_V_PP = 1 / 2 * V_out_no_load_V_PP

print_value("V_out_V_PP", V_out_V_PP)

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch08_05_ep07_02_1_result_plot.png", width=700)

# %% [markdown]
# 가변저항을 회로에서 분리하여, 저항계로 측정하면, 그 값이 출력저항값이 된다.

# %% [markdown]
# |                 | 예시값          | 측정값           |
# |-----------------|-----------------|------------------|
# | R_out (kOhm)    | 3               | ??               |

# %% [markdown]
# [검증] 실험 7-1의 결과를 검증해 본다.

# %%
V_out_no_load_V_PP = ?? # 무부하 출력값
R_out_Ohm = ??

# %%
R_L_Ohm = 200
V_out_V_PP = R_L_Ohm / (R_out_Ohm + R_L_Ohm) * V_out_no_load_V_PP

print_value("V_out_V_PP", V_out_V_PP)

# %% [markdown]
# * [고찰] 실험07-01 부하효과 실험의 결과와 비교해본다.

# %% [markdown]
# ### 실험08 CE증폭기2 회로의 재실험

# %% [markdown]
# * 예비문제 3에서 설계한 회로를 구성한다.
# * 실험 5 ~ 실험 7의 내용

# %% [markdown]
# 설계한 회로도

# %%
display_image("./data/ch08_05_ep08_01_circuit.png", width=300)

# %% [markdown]
# #### 실험08-01 회로를 만든다.

# %% [markdown]
# 구성한 회로의 사진을 찍는다.

# %%
display_image("./data/ch08_05_ep08_01_circuit_hardware.png", width=700)

# %% [markdown]
# DMM을 이용하여 V_CE 값을 측정하라.
#
# I_C 는 전류계를 사용하지 말고 다음과 같이 계산하라.

# %%
V_CE_V = ??

# %%
V_CC_V = 12
R_C_Ohm = 1300
R_E_Ohm = 430

I_C_mA = (V_CC_V - V_CE_V) / (R_C_Ohm + R_E_Ohm) * 1000

print_value("I_C_mA", I_C_mA)

# %% [markdown]
# |                 | 해석         | 측정값       |
# |-----------------|--------------|--------------|
# | V_CE (V)        | ??           | ??           |
# | I_C (mA)        | ??           | ??           |

# %% [markdown]
# #### 실험08-02 R_2 저항값의 변화에 대한 민감도 실험

# %% [markdown]
# R_2 저항을 다음과 같이 한 단계 낮춰 다시 측정한다.

# %% [markdown]
# ??

# %% [markdown]
# |                 | 해석         | 측정값       |
# |-----------------|--------------|--------------|
# | V_CE (V)        | ??           | ??           |

# %% [markdown]
# R_2 저항을 다음과 같이 한 높여 다시 측정한다.

# %% [markdown]
# ??

# %% [markdown]
# |                 | 해석         | 측정값       |
# |-----------------|--------------|--------------|
# | V_CE (V)        | ??           | ??           |

# %% [markdown]
# 다음 실험을 위해 R_2 저항을 원상 복구 시킨다.

# %% [markdown]
# #### 실험08-03 온도의 변화에 대한 민감도 실험

# %% [markdown]
# 온도의 변화에 대한 실험을 한다.
# * 트랜지스터를 손으로 10초 동안 잡는다.

# %% [markdown]
# |                 | 측정값       |
# |-----------------|--------------|
# | V_CE (V)        | ??           |

# %% [markdown]
# * [검토] 온도가 올라가면 => I_C 가 증가하고 => V_CE 는 감소한다.
# * [검토] 증폭기1 회로에 비해, 큰 차이를 보이지 않는다.

# %% [markdown]
# 손을 놓으면 V_CE 가 서서히 원상복구된다.

# %% [markdown]
# 헤어드라이기를 이용하여 강력하게 열을 전달해보자.
# * 헤어드라이기를 5초 동안 이용한다.
# * V_CE 가 강력하게 감소하는 것만 확인한다.

# %% [markdown]
# |                 | 측정값       |
# |-----------------|--------------|
# | V_CE (V)        | ??           |

# %% [markdown]
# * [검토] 증폭기1 회로에 비해, 큰 차이를 보이지 않는다.

# %% [markdown]
# #### 실험08-04 교류증폭 실험

# %% [markdown]
# 입력 v_i 에 다음 정현파를 인가하자 (파형발생기를 이용)
#
# * f = 1 kHz
# * 1 V_PP

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %% [markdown]
# * 채널2의 직류전압성분을 제거하기 위하여, 채널2의 커플링을 AC모드로 변환한다.

# %%
display_image("./data/ch08_05_ep08_04_result_plot.png", width=700)

# %% [markdown]
# 자동측정으로 출력의 Vpp를 측정한다.

# %% [markdown]
# |                 | 측정값       |
# |-----------------|--------------|
# | 출력의 V_PP     | ??           |

# %% [markdown]
# * [검토] 이 증폭기의 대략적인 전압이득은 A_V = - R_C / R_E = -3 이다.
#     + 위상이 반전되었으므로 이득은 음수값을 가진다.

# %% [markdown]
# #### 실험08-05 최대 입력전압

# %% [markdown]
# 입력전압의 크기를 키워보자!
#
# 입력을 V_PP = 4 V으로 하면, 출력파형에 왜곡이 생긴다.

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch08_05_ep08_04_1_result_plot.png", width=700)

# %% [markdown]
# 입력전압을 서서히 줄여서, 출력전압에 왜곡이 없는 때를 찾아라.

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch08_05_ep08_04_2_result_plot.png", width=700)

# %% [markdown]
# 왜곡이 없어지는 입력 전압을 기록한다.

# %% [markdown]
# ?? V_PP

# %% [markdown]
# #### 실험08-05 민감도 실험

# %% [markdown]
# R_2 저항을 다음과 같이 한 단계 낮춰 다시 측정한다.

# %% [markdown]
# ??

# %%
display_image("./data/ch08_05_ep08_05_1_result_plot.png", width=700)

# %% [markdown]
# * [결과] 동작점이 차단영역쪽으로 약간 이동한다.

# %% [markdown]
# R_2 저항을 다음과 같이 한 높여 다시 측정한다.

# %% [markdown]
# ??

# %%
display_image("./data/ch08_05_ep08_05_2_result_plot.png", width=700)

# %% [markdown]
# * [결과] 동작점이 포화영역쪽으로 약간 이동한다.

# %% [markdown]
# 왜곡이 일어나지 않도록 입력전압의 크기를 줄여보자.

# %%
display_image("./data/ch08_05_ep08_05_3_result_plot.png", width=700)

# %% [markdown]
# * [결과] 진폭을 2.7V로 감소했을 때, 왜곡이 일어나지 않는다.
# * [결론] 바이어스가 제대로 잡혀있지 않으면, 출력의 크기에 제한이 생긴다.

# %% [markdown]
# 다음 실험을 위해 R_2 저항을 원상 복구 시킨다.

# %% [markdown]
# #### 실험08-06 부하효과

# %% [markdown]
# 입력 v_i 에 다음 정현파를 인가하자 (파형발생기를 이용)
#
# * f = 1 kHz
# * 2 V_PP

# %%
display_image("./data/ch08_05_ep08_06_1_result_plot.png", width=700)

# %% [markdown]
# 다음과 같이 부하저항 200 Ohm을 연결한다.

# %% [markdown]
# 출력의 V_PP 를 측정한다.

# %%
display_image("./data/ch08_05_ep08_06_2_result_plot.png", width=700)

# %% [markdown]
# |                 | 측정값 (V_PP)    |
# |-----------------|------------------|
# | 무부하          | ??               |
# | 부하            | ??               |

# %% [markdown]
# * [결과] 심각한 부하효과가 나타난다.

# %% [markdown]
# #### 실험08-07 출력저항 R_O의 측정

# %% [markdown]
# 디음과 같이 부하저항 200 Ohm을 제거하고, 5 kOhm 가변저항을 연결한다.

# %% [markdown]
# 저항값을 가변하여서 출력전압이 무부하일 때의 반값이 되도록 한다.

# %%
V_out_no_load_V_PP = ??

# %%
V_out_V_PP = 1 / 2 * V_out_no_load_V_PP

print_value("V_out_V_PP", V_out_V_PP)

# %% [markdown]
# 오실로스코프로 측정해보자
#
# * CH1 : v_i
# * CH2 : v_o

# %%
display_image("./data/ch08_05_ep08_07_1_result_plot.png", width=700)

# %% [markdown]
# 가변저항을 회로에서 분리하여, 저항계로 측정하면, 그 값이 출력저항값이 된다.

# %% [markdown]
# |                 | 측정값           |
# |-----------------|------------------|
# | R_out (kOhm)    | ??               |

# %% [markdown]
# [검증] 실험 7-1의 결과를 검증해 본다.

# %%
V_out_no_load_V_PP = ?? # 무부하 출력값
R_out_Ohm = ??

# %%
R_L_Ohm = 200
V_out_V_PP = R_L_Ohm / (R_out_Ohm + R_L_Ohm) * V_out_no_load_V_PP

print_value("V_out_V_PP", V_out_V_PP)

# %% [markdown]
# * [고찰] 실험07-01 부하효과 실험의 결과와 비교해본다.
